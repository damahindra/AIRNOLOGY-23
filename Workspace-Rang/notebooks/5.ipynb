# %% [markdown]
# ### Airnology 2023

# %% [markdown]
# #### Descriptions

# %% [markdown]
# **datetime**            : Waktu ketika data dihitung (dalam format timestamp UNIX).
#
# **datetime_iso**        : Waktu dalam format ISO 8601, termasuk zona waktu.
#
# **time-zone**           : Zona waktu dalam detik terhadap UTC.
#
# **temp**                : Suhu saat ini dalam Celcius.
#
# **visibility**          : Visibilitas rata-rata dalam meter.
#
# **d_point**             : Titik embun saat ini dalam Celcius.
#
# **feels**               : Suhu yang dirasakan saat ini dalam Celcius.
#
# **min_temp**            : Suhu minimum dalam rentang waktu tertentu dalam Celcius.
#
# **max_temp**            : Suhu maksimum dalam rentang waktu tertentu dalam Celcius.
#
# **pressure**            : Tekanan atmosfer dalam hPa .
#
# **sea_level**           : Tekanan atmosfer pada permukaan laut dalam hPa.
#
# **grnd_level**          : Tekanan atmosfer pada permukaan tanah dalam hPa.
#
# **hum**                 : Persentase kelembaban udara saat ini.
#
# **wind_spd**            : Kecepatan angin saat ini dalam m/s.
#
# **wind_deg**            : Arah angin dalam derajat.
#
# **rain_1h**             : Curah hujan dalam 1 jam terakhir dalam mm. (variabel target)
#
# **rain_3h**             : Curah hujan dalam 3 jam terakhir dalam mm.
#
# **snow_1h**             : Curah salju dalam 1 jam terakhir dalam mm.
#
# **snow_3h**             : Curah salju dalam 3 jam terakhir dalam mm.
#
# **clouds**              : Persentase penutupan awan saat ini.

# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
import scipy.stats

# %% [markdown]
# #### Methods

# %%
# cleaning methods

def clean_temp(temp) :
    if isinstance(temp, str) :
        temp = temp.replace(' Celcius', '')
        temp = temp.replace(' C', '')
        temp = temp.replace('°C', '')
    return temp

def clean_rain(rain) :
    if isinstance(rain, str) :
        try :
            float(rain)
            return rain
        except :
            new_rain = 0
            return new_rain
        
def clean_wind(wind) :
    if isinstance(wind, str) :
        wind = wind.replace('°', '')
        wind = wind.replace('m/s', '')
    return wind

def clean_visibility(visibility) :
    if isinstance(visibility, str) :
        if visibility in ['unidentified', ' ', 'unrecognized', 'unknown', 'empty', 'undefined', 'missing'] :
            return 'unknown'
        elif visibility in ['-1m', '-1 m'] :
            return '-1m'
        elif visibility in ['-1km', '-1 km'] :
            return '-1km'
    return visibility

def clean_ground_and_sea(ground_and_sea) :
    if isinstance(ground_and_sea, str) :
        if ground_and_sea in ['undetermined', 'unsettled', 'unestablished', 'not recorded', 'unknown', 'not_recorded', 'not-recorded','unspecified'] :
            return 'unknown'
    return ground_and_sea
    
def clean_prssr(prssr) :
    if isinstance(prssr, str) :
        if prssr in ['-100.0 hPa.', '-100.0 hPa', '-100'] :
            return 99.0
        prssr = prssr.replace('hPa.', '')
        prssr = prssr.replace('hPa', '')
    return prssr

def clean_hum(hum) :
    if isinstance(hum, str) :
        hum = hum.replace('%', '')
    return hum

def clean_cloud(cloud) :
    if isinstance(cloud, str) :
        cloud = cloud.replace('%', '')
    return cloud

def categorize_hour(hour) :
    if hour in [4,5]:
        return "dawn"
    elif hour in [6,7]:
        return "early morning"
    elif hour in [8,9,10]:
        return "late morning"
    elif hour in [11,12,13]:
        return "noon"
    elif hour in [14,15,16]:
        return "afternoon"
    elif hour in [17, 18,19]:
        return "evening"
    elif hour in [20, 21, 22]:
        return "night"
    elif hour in [23,0,1,2,3]:
        return "midnight"

# impute
def knn_impute(df, na_target) :
    df = df.copy()

    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[:, numeric_df.isna().sum() == 0].columns

    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]

    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)

    y_pred = knn.predict(X_test)

    df.loc[df[na_target].isna() == True, na_target] = y_pred

    return df

# %% [markdown]
# #### Data Overview

# %%
train = pd.read_csv('../../datasets/train.csv')
test = pd.read_csv('../../datasets/test.csv')

TARGET = 'rain_1h'
# train.drop('rain_1h', axis=1, inplace=True)

# %%
train.isna().sum()
# Out:
# datetime             0
# datetime_iso         0
# time-zone            0
# temp                 0
# visibility      290768
# d_point              0
# feels                0
# min_temp             0
# max_temp             0
# prssr                0
# sea_level       148916
# grnd_level      148961
# hum                  0
# wind_spd             0
# wind_deg             0
# rain_1h              0
# rain_3h         149551
# snow_1h         149184
# snow_3h         149181
# clouds               0
# dtype: int64

# %%
print(f'train shape : {train.shape}')
print(f'test shape : {test.shape}')
# Out:
# train shape : (341880, 20)
# test shape : (49368, 19)

# %% [markdown]
# #### Merging train and test

# %%
# # merging train2 and test data
# merged = pd.concat([train2, test], axis = 0).reset_index(drop=True) 
# merged.drop(['datetime', 'snow_1h', 'snow_3h', 'time-zone'], axis=1, inplace=True)
# merged.set_index('datetime_iso', drop=True, inplace=True)

train2 = train.copy()


drop_cols = ['datetime', 'snow_1h', 'snow_3h', 'time-zone']

train2.drop(drop_cols, axis=1, inplace=True)
test.drop(drop_cols, axis=1, inplace=True)

# converting temp dtypes
for column in ['temp','d_point','feels','min_temp','max_temp'] :
    train2[column] = train2[column].apply(lambda x: clean_temp(x))
    train2[column] = train2[column].astype('float64')

    test[column] = test[column].apply(lambda x: clean_temp(x))
    test[column] = test[column].astype('float64')

# converting rain dtypes
for column in [TARGET, 'rain_3h'] :
    train2[column] = train2[column].apply(lambda x: clean_rain(x))
    train2[column] = train2[column].astype('float64')

for column in ['rain_3h'] :
    test[column] = test[column].apply(lambda x: clean_rain(x))
    test[column] = test[column].astype('float64')

# converting wind dtypes
for column in ['wind_spd', 'wind_deg'] :
    train2[column] = train2[column].apply(lambda x: clean_wind(x))
    train2[column] = train2[column].astype('float64')

    test[column] = test[column].apply(lambda x: clean_wind(x))
    test[column] = test[column].astype('float64')

# cleaning visibility
for column in ['visibility'] :
    train2[column] = train2[column].apply(lambda x: clean_visibility(x))
    train2[column] = train2[column].fillna(train2[column].mode().iloc[0])

    test[column] = test[column].apply(lambda x: clean_visibility(x))
    test[column] = test[column].fillna(train2[column].mode().iloc[0])

# cleaning ground and sea level
for column in ['sea_level', 'grnd_level'] :
    train2[column] = train2[column].apply(lambda x: clean_ground_and_sea(x))
    train2[column] = train2[column].fillna(train2[column].mode().iloc[0])

    test[column] = test[column].apply(lambda x: clean_ground_and_sea(x))
    test[column] = test[column].fillna(train2[column].mode().iloc[0])

# cleaning pressure
for column in ['prssr'] :
    train2[column] = train2[column].apply(lambda x: clean_prssr(x))
    train2[column] = train2[column].astype('float64')

    test[column] = test[column].apply(lambda x: clean_prssr(x))
    test[column] = test[column].astype('float64')
    
# cleaning humidity
for column in ['hum'] :
    train2[column] = train2[column].apply(lambda x: clean_hum(x))
    train2[column] = train2[column].astype('float64')

    test[column] = test[column].apply(lambda x: clean_hum(x))
    test[column] = test[column].astype('float64')

# cleaning clouds 
for column in ['clouds'] :
    train2[column] = train2[column].apply(lambda x: clean_cloud(x))
    train2[column] = train2[column].astype('float64')

    test[column] = test[column].apply(lambda x: clean_cloud(x))
    test[column] = test[column].astype('float64')

# preprocessing train
train2['datetime_iso'] = pd.to_datetime(train2['datetime_iso'])

train2['month'] = train2['datetime_iso'].dt.month

# train2['date_issued:day_of_week'] = train2['datetime_iso'].dt.day_of_week
# train2['date_issued:day_of_week'] = train2['date_issued:day_of_week'].astype(str)

train2['day_of_year'] = train2['datetime_iso'].dt.day_of_year
# train2['date_issued:day_of_year'] = train2['date_issued:day_of_year'].astype(str)

train2['day'] = train2['datetime_iso'].dt.day
train2['day'] = train2['day'].astype(str)

train2['hour'] = train2['datetime_iso'].dt.hour
train2['hour_cat'] = train2['hour'].apply(categorize_hour)
train2['hour'] = train2['hour'].astype(str)

train2 = train2.set_index('datetime_iso')

# preprocessing test
test['datetime_iso'] = pd.to_datetime(test['datetime_iso'])

test['month'] = test['datetime_iso'].dt.month

# test['date_issued:day_of_week'] = test['datetime_iso'].dt.day_of_week
# test['date_issued:day_of_week'] = test['date_issued:day_of_week'].astype(str)

test['day_of_year'] = test['datetime_iso'].dt.day_of_year
# test['date_issued:day_of_year'] = test['date_issued:day_of_year'].astype(str)

test['day'] = test['datetime_iso'].dt.day
test['day'] = test['day'].astype(str)

test['hour'] = test['datetime_iso'].dt.hour
test['hour_cat'] = test['hour'].apply(categorize_hour)
test['hour'] = test['hour'].astype(str)

test = test.set_index('datetime_iso')

# column transform from month to season
train2['month']= np.sin(-0.449 * (train2['month'] - 3))
test['month']= np.sin(-0.449 * (test['month'] - 3))

# column transform day of year
train2['day_of_year']= 55 * (np.sin(0.015 * (train2['day_of_year'] - 60)))
test['day_of_year']= 55 * (np.sin(0.015 * (test['day_of_year'] - 60)))

# %% [markdown]
# #### Capping Outliers

# %%
train3 = train2[train2["rain_1h"] >= 0]

MAX_TEMP = 50
MAX_HUM = 150
MAX_MAX_TEMP = 50
MAX_FEELS = 60
MAX_PRESSURE  = 1200
MAX_MIN_TENP = 60

print(train3.shape)
train3 = train3[train3["max_temp"] < MAX_MAX_TEMP]
train3 = train3[train3["hum"] < MAX_HUM]
train3 = train3[train3["feels"] < MAX_FEELS]
train3 = train3[train3["prssr"] < MAX_PRESSURE]
train3 = train3[train3["min_temp"] < MAX_MIN_TENP]
train3 = train3[train3["temp"] < MAX_TEMP]
train3["wind_deg"] = train3["wind_deg"].apply(lambda x: x % 360 if x > 360 else x)
print(train3.shape)
# Out:
# (341880, 20)
# (312278, 20)

# %% [markdown]
# #### Imputer

# %%
train3.isna().sum()
# Out:
# temp                0
# visibility          0
# d_point             0
# feels               0
# min_temp            0
# max_temp            0
# prssr               0
# sea_level           0
# grnd_level          0
# hum                 0
# wind_spd            0
# wind_deg            0
# rain_1h             0
# rain_3h        136644
# clouds              0
# month               0
# day_of_year         0
# day                 0
# hour                0
# hour_cat            0
# dtype: int64

# %%
# imputing with knn
train4 = train3.copy()
for column in ['rain_3h'] :
    train4 = knn_impute(train4, column)
    test = knn_impute(test, column)
    
for column in ['d_point'] :
    test = knn_impute(test, column)

train4

# # imputing with mean
# merged2 = merged.copy()
# for column in ['d_point','rain_3h'] :
#     merged2[column] = merged[column].fillna(merged[column].mean())

# merged2
# Out:
#                             temp visibility  d_point  feels  min_temp  \
# datetime_iso
# 1979-01-01 00:00:00+00:00  24.75    unknown    23.89  25.76     24.28
# 1979-01-01 01:00:00+00:00  24.58    unknown    23.73  25.57     23.99
# 1979-01-01 02:00:00+00:00  26.60    unknown    24.06  26.60     26.10
# 1979-01-01 03:00:00+00:00  27.31    unknown    24.37  30.90     26.59
# 1979-01-01 04:00:00+00:00  27.41    unknown    25.05  31.54     26.58
# ...                          ...        ...      ...    ...       ...
# 2017-12-31 17:00:00+00:00  25.34    unknown    24.83  26.46     24.75
# 2017-12-31 18:00:00+00:00  25.11    unknown    24.60  26.21     24.59
# 2017-12-31 20:00:00+00:00  24.51    unknown    24.17  25.58     23.89
# 2017-12-31 22:00:00+00:00  26.68    unknown    24.71  29.76     25.02
# 2017-12-31 23:00:00+00:00  26.49    unknown    24.90  26.49     26.02
#
#                            max_temp   prssr sea_level grnd_level   hum  \
# datetime_iso
# 1979-01-01 00:00:00+00:00     25.22  1012.0   unknown    unknown  95.0
# 1979-01-01 01:00:00+00:00     25.26  1012.0   unknown    unknown  95.0
# 1979-01-01 02:00:00+00:00     27.39  1012.0   unknown    unknown  86.0
# 1979-01-01 03:00:00+00:00     28.36  1012.0   unknown    unknown  84.0
# 1979-01-01 04:00:00+00:00     28.31  1011.0   unknown    unknown  87.0
# ...                             ...     ...       ...        ...   ...
# 2017-12-31 17:00:00+00:00     26.04  1008.0   unknown    unknown  97.0
# 2017-12-31 18:00:00+00:00     25.62  1007.0   unknown    unknown  97.0
# 2017-12-31 20:00:00+00:00     25.13  1006.0   unknown    unknown  98.0
# 2017-12-31 22:00:00+00:00     27.25  1008.0   unknown    unknown  89.0
# 2017-12-31 23:00:00+00:00     27.09  1008.0   unknown    unknown  91.0
#
#                            wind_spd  wind_deg  rain_1h  rain_3h  clouds  \
# datetime_iso
# 1979-01-01 00:00:00+00:00      0.82     320.0     0.00      0.0   100.0
# 1979-01-01 01:00:00+00:00      0.96     338.0     0.00      0.0   100.0
# 1979-01-01 02:00:00+00:00      1.22     339.0     0.00      0.0    99.0
# 1979-01-01 03:00:00+00:00      1.08     342.0     0.13      0.0    94.0
# 1979-01-01 04:00:00+00:00      0.86     336.0     0.34      0.0   100.0
# ...                             ...       ...      ...      ...     ...
# 2017-12-31 17:00:00+00:00      0.12     188.0     2.66      0.0   100.0
# 2017-12-31 18:00:00+00:00      0.98      21.0     0.00      0.0   100.0
# 2017-12-31 20:00:00+00:00      0.85      21.0     0.00      0.0   100.0
# 2017-12-31 22:00:00+00:00      1.46      17.0     0.00      0.0    98.0
# 2017-12-31 23:00:00+00:00      1.56       6.0     0.19      0.0    99.0
#
#                               month  day_of_year day hour  hour_cat
# datetime_iso
# 1979-01-01 00:00:00+00:00  0.782082   -42.565324   1    0  midnight
# 1979-01-01 01:00:00+00:00  0.782082   -42.565324   1    1  midnight
# 1979-01-01 02:00:00+00:00  0.782082   -42.565324   1    2  midnight
# 1979-01-01 03:00:00+00:00  0.782082   -42.565324   1    3  midnight
# 1979-01-01 04:00:00+00:00  0.782082   -42.565324   1    4      dawn
# ...                             ...          ...  ..  ...       ...
# 2017-12-31 17:00:00+00:00  0.782958   -54.481733  31   17   evening
# 2017-12-31 18:00:00+00:00  0.782958   -54.481733  31   18   evening
# 2017-12-31 20:00:00+00:00  0.782958   -54.481733  31   20     night
# 2017-12-31 22:00:00+00:00  0.782958   -54.481733  31   22     night
# 2017-12-31 23:00:00+00:00  0.782958   -54.481733  31   23  midnight
#
# [312278 rows x 20 columns]

# %%
train4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 312278 entries, 1979-01-01 00:00:00+00:00 to 2017-12-31 23:00:00+00:00
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   temp         312278 non-null  float64
#  1   visibility   312278 non-null  object
#  2   d_point      312278 non-null  float64
#  3   feels        312278 non-null  float64
#  4   min_temp     312278 non-null  float64
#  5   max_temp     312278 non-null  float64
#  6   prssr        312278 non-null  float64
#  7   sea_level    312278 non-null  object
#  8   grnd_level   312278 non-null  object
#  9   hum          312278 non-null  float64
#  10  wind_spd     312278 non-null  float64
#  11  wind_deg     312278 non-null  float64
#  12  rain_1h      312278 non-null  float64
#  13  rain_3h      312278 non-null  float64
#  14  clouds       312278 non-null  float64
#  15  month        312278 non-null  float64
#  16  day_of_year  312278 non-null  float64
#  17  day          312278 non-null  object
#  18  hour         312278 non-null  object
#  19  hour_cat     312278 non-null  object
# dtypes: float64(14), object(6)
# memory usage: 50.0+ MB

# %% [markdown]
# #### Transformations

# %%
very_skewed_col = []
num_cols = train4.select_dtypes(np.number)
for column in num_cols :
    skew = scipy.stats.skew(train4[column])
    print(f'{column} skewness : {skew}')
    if skew > 0.5 or skew < -0.5 :
        very_skewed_col.append(column)

print(very_skewed_col)
# Out:
# temp skewness : 0.6603544548266891
# d_point skewness : 7.908324917944134
# feels skewness : 0.6995901014134408
# min_temp skewness : 0.5625930127787475
# max_temp skewness : 0.6445112697468711
# prssr skewness : -0.20421068827097205
# hum skewness : -1.1640478084317862
# wind_spd skewness : 5.200931091784641
# wind_deg skewness : -0.32973978725682096
# rain_1h skewness : 6.7224247502743015
# rain_3h skewness : nan
# clouds skewness : -1.784178447731747
# month skewness : 0.18767254222517527
# day_of_year skewness : -0.20257793535651178
# ['temp', 'd_point', 'feels', 'min_temp', 'max_temp', 'hum', 'wind_spd', 'rain_1h', 'clouds']

# %%
# train5 = train4.copy()
# for column in ['temp', 'feels', 'min_temp', 'max_temp', 'wind_spd', 'clouds', 'd_point', 'hum'] :
#     train5[column] = np.log1p(train5[column])
#     test[column] = np.log1p(test[column])

# for column in ['d_point', 'hum'] :
#     train5[column], _lambda = scipy.stats.boxcox(train5[column])
#     test[column] = scipy.stats.boxcox(test[column], lmbda=_lambda)

# num_cols = train5.select_dtypes(np.number)
# for column in num_cols :
#     skew = scipy.stats.skew(train5[column])
#     print(f'{column} skewness : {skew}')

# %%
test.isna().sum()
# Out:
# temp           0
# visibility     0
# d_point        0
# feels          0
# min_temp       0
# max_temp       0
# prssr          0
# sea_level      0
# grnd_level     0
# hum            0
# wind_spd       0
# wind_deg       0
# rain_3h        0
# clouds         0
# month          0
# day_of_year    0
# day            0
# hour           0
# hour_cat       0
# dtype: int64

# %% [markdown]
# #### Target Transformation

# %%
train5 = train4.copy()
# train5[TARGET] = np.log(train5[TARGET])

# %% [markdown]
# #### Encoding

# %%
train6 = pd.get_dummies(train5)
test = pd.get_dummies(test)

# %%
print(train6.shape)
print(test.shape)
# Out:
# (312278, 85)
# (49368, 84)

# %%
train6
# Out:
#                             temp  d_point  feels  min_temp  max_temp   prssr  \
# datetime_iso
# 1979-01-01 00:00:00+00:00  24.75    23.89  25.76     24.28     25.22  1012.0
# 1979-01-01 01:00:00+00:00  24.58    23.73  25.57     23.99     25.26  1012.0
# 1979-01-01 02:00:00+00:00  26.60    24.06  26.60     26.10     27.39  1012.0
# 1979-01-01 03:00:00+00:00  27.31    24.37  30.90     26.59     28.36  1012.0
# 1979-01-01 04:00:00+00:00  27.41    25.05  31.54     26.58     28.31  1011.0
# ...                          ...      ...    ...       ...       ...     ...
# 2017-12-31 17:00:00+00:00  25.34    24.83  26.46     24.75     26.04  1008.0
# 2017-12-31 18:00:00+00:00  25.11    24.60  26.21     24.59     25.62  1007.0
# 2017-12-31 20:00:00+00:00  24.51    24.17  25.58     23.89     25.13  1006.0
# 2017-12-31 22:00:00+00:00  26.68    24.71  29.76     25.02     27.25  1008.0
# 2017-12-31 23:00:00+00:00  26.49    24.90  26.49     26.02     27.09  1008.0
#
#                             hum  wind_spd  wind_deg  rain_1h  ...  hour_8  \
# datetime_iso                                                  ...
# 1979-01-01 00:00:00+00:00  95.0      0.82     320.0     0.00  ...       0
# 1979-01-01 01:00:00+00:00  95.0      0.96     338.0     0.00  ...       0
# 1979-01-01 02:00:00+00:00  86.0      1.22     339.0     0.00  ...       0
# 1979-01-01 03:00:00+00:00  84.0      1.08     342.0     0.13  ...       0
# 1979-01-01 04:00:00+00:00  87.0      0.86     336.0     0.34  ...       0
# ...                         ...       ...       ...      ...  ...     ...
# 2017-12-31 17:00:00+00:00  97.0      0.12     188.0     2.66  ...       0
# 2017-12-31 18:00:00+00:00  97.0      0.98      21.0     0.00  ...       0
# 2017-12-31 20:00:00+00:00  98.0      0.85      21.0     0.00  ...       0
# 2017-12-31 22:00:00+00:00  89.0      1.46      17.0     0.00  ...       0
# 2017-12-31 23:00:00+00:00  91.0      1.56       6.0     0.19  ...       0
#
#                            hour_9  hour_cat_afternoon  hour_cat_dawn  \
# datetime_iso
# 1979-01-01 00:00:00+00:00       0                   0              0
# 1979-01-01 01:00:00+00:00       0                   0              0
# 1979-01-01 02:00:00+00:00       0                   0              0
# 1979-01-01 03:00:00+00:00       0                   0              0
# 1979-01-01 04:00:00+00:00       0                   0              1
# ...                           ...                 ...            ...
# 2017-12-31 17:00:00+00:00       0                   0              0
# 2017-12-31 18:00:00+00:00       0                   0              0
# 2017-12-31 20:00:00+00:00       0                   0              0
# 2017-12-31 22:00:00+00:00       0                   0              0
# 2017-12-31 23:00:00+00:00       0                   0              0
#
#                            hour_cat_early morning  hour_cat_evening  \
# datetime_iso
# 1979-01-01 00:00:00+00:00                       0                 0
# 1979-01-01 01:00:00+00:00                       0                 0
# 1979-01-01 02:00:00+00:00                       0                 0
# 1979-01-01 03:00:00+00:00                       0                 0
# 1979-01-01 04:00:00+00:00                       0                 0
# ...                                           ...               ...
# 2017-12-31 17:00:00+00:00                       0                 1
# 2017-12-31 18:00:00+00:00                       0                 1
# 2017-12-31 20:00:00+00:00                       0                 0
# 2017-12-31 22:00:00+00:00                       0                 0
# 2017-12-31 23:00:00+00:00                       0                 0
#
#                            hour_cat_late morning  hour_cat_midnight  \
# datetime_iso
# 1979-01-01 00:00:00+00:00                      0                  1
# 1979-01-01 01:00:00+00:00                      0                  1
# 1979-01-01 02:00:00+00:00                      0                  1
# 1979-01-01 03:00:00+00:00                      0                  1
# 1979-01-01 04:00:00+00:00                      0                  0
# ...                                          ...                ...
# 2017-12-31 17:00:00+00:00                      0                  0
# 2017-12-31 18:00:00+00:00                      0                  0
# 2017-12-31 20:00:00+00:00                      0                  0
# 2017-12-31 22:00:00+00:00                      0                  0
# 2017-12-31 23:00:00+00:00                      0                  1
#
#                            hour_cat_night  hour_cat_noon
# datetime_iso
# 1979-01-01 00:00:00+00:00               0              0
# 1979-01-01 01:00:00+00:00               0              0
# 1979-01-01 02:00:00+00:00               0              0
# 1979-01-01 03:00:00+00:00               0              0
# 1979-01-01 04:00:00+00:00               0              0
# ...                                   ...            ...
# 2017-12-31 17:00:00+00:00               0              0
# 2017-12-31 18:00:00+00:00               0              0
# 2017-12-31 20:00:00+00:00               1              0
# 2017-12-31 22:00:00+00:00               1              0
# 2017-12-31 23:00:00+00:00               0              0
#
# [312278 rows x 85 columns]

# %% [markdown]
# #### Scaling

# %%
# splitting the dataset

X = train6.drop(TARGET, axis=1)
y = train6[TARGET]

# Train tets split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=101)

# %%
X_train.columns
# Out:
# Index(['temp', 'd_point', 'feels', 'min_temp', 'max_temp', 'prssr', 'hum',
#        'wind_spd', 'wind_deg', 'rain_3h', 'clouds', 'month', 'day_of_year',
#        'visibility_-1', 'visibility_-1km', 'visibility_-1m',
#        'visibility_unknown', 'sea_level_-1', 'sea_level_unknown',
#        'grnd_level_-1', 'grnd_level_unknown', 'day_1', 'day_10', 'day_11',
#        'day_12', 'day_13', 'day_14', 'day_15', 'day_16', 'day_17', 'day_18',
#        'day_19', 'day_2', 'day_20', 'day_21', 'day_22', 'day_23', 'day_24',
#        'day_25', 'day_26', 'day_27', 'day_28', 'day_29', 'day_3', 'day_30',
#        'day_31', 'day_4', 'day_5', 'day_6', 'day_7', 'day_8', 'day_9',
#        'hour_0', 'hour_1', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
#        'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
#        'hour_2', 'hour_20', 'hour_21', 'hour_22', 'hour_23', 'hour_3',
#        'hour_4', 'hour_5', 'hour_6', 'hour_7', 'hour_8', 'hour_9',
#        'hour_cat_afternoon', 'hour_cat_dawn', 'hour_cat_early morning',
#        'hour_cat_evening', 'hour_cat_late morning', 'hour_cat_midnight',
#        'hour_cat_night', 'hour_cat_noon'],
#       dtype='object')

# %%
train5.isna().sum()
# Out:
# temp           0
# visibility     0
# d_point        0
# feels          0
# min_temp       0
# max_temp       0
# prssr          0
# sea_level      0
# grnd_level     0
# hum            0
# wind_spd       0
# wind_deg       0
# rain_1h        0
# rain_3h        0
# clouds         0
# month          0
# day_of_year    0
# day            0
# hour           0
# hour_cat       0
# dtype: int64

# %%
all_cols = X_train.columns
num_cols = ['temp', 'd_point', 'feels', 'min_temp', 'max_temp', 'prssr', 'hum',
       'wind_spd', 'wind_deg', 'rain_3h', 'clouds', 'month',
       'day_of_year']
cat_cols = np.setdiff1d(all_cols, num_cols)

scaler = StandardScaler()
scaler.fit(X_train[num_cols])

X_train_scaled = pd.concat([pd.DataFrame(scaler.transform(X_train[num_cols]), columns=num_cols, index=X_train.index), X_train[cat_cols]], axis=1)
X_test_scaled = pd.concat([pd.DataFrame(scaler.transform(X_test[num_cols]), columns=num_cols, index=X_test.index), X_test[cat_cols]], axis=1)

# full data
X_scaled = pd.concat([pd.DataFrame(scaler.transform(X[num_cols]), columns=num_cols, index=X.index), X[cat_cols]], axis=1)
test_scaled = pd.concat([pd.DataFrame(scaler.transform(test[num_cols]), columns=num_cols, index=test.index), test[cat_cols]], axis=1)

# %%
cb_regressor = CatBoostRegressor(iterations=35000, early_stopping_rounds=10)
xgb_regressor = XGBRegressor()
lgbm_regressor = LGBMRegressor()


cb_regressor.fit(X_scaled, y)
# Out:
# Learning rate set to 0.005636
# 0:	learn: 0.7048569	total: 27.4ms	remaining: 16m
# 1:	learn: 0.7044853	total: 50.1ms	remaining: 14m 37s
# 2:	learn: 0.7041122	total: 78.5ms	remaining: 15m 16s
# 3:	learn: 0.7037428	total: 108ms	remaining: 15m 44s
# 4:	learn: 0.7033775	total: 133ms	remaining: 15m 32s
# 5:	learn: 0.7030175	total: 156ms	remaining: 15m 9s
# 6:	learn: 0.7026605	total: 183ms	remaining: 15m 13s
# 7:	learn: 0.7023082	total: 205ms	remaining: 14m 57s
# 8:	learn: 0.7019570	total: 232ms	remaining: 15m 2s
# 9:	learn: 0.7016106	total: 263ms	remaining: 15m 20s
# 10:	learn: 0.7012678	total: 287ms	remaining: 15m 12s
# 11:	learn: 0.7009269	total: 312ms	remaining: 15m 8s
# 12:	learn: 0.7005999	total: 334ms	remaining: 14m 59s
# 13:	learn: 0.7002729	total: 361ms	remaining: 15m 2s
# 14:	learn: 0.6999441	total: 385ms	remaining: 14m 56s
# 15:	learn: 0.6996233	total: 412ms	remaining: 15m
# 16:	learn: 0.6993033	total: 436ms	remaining: 14m 57s
# 17:	learn: 0.6989854	total: 463ms	remaining: 15m
# 18:	learn: 0.6986751	total: 488ms	remaining: 14m 57s
# 19:	learn: 0.6983601	total: 513ms	remaining: 14m 56s
# 20:	learn: 0.6980502	total: 536ms	remaining: 14m 52s
# 21:	learn: 0.6977481	total: 560ms	remaining: 14m 50s
# 22:	learn: 0.6974451	total: 583ms	remaining: 14m 46s
# 23:	learn: 0.6971450	total: 609ms	remaining: 14m 47s
# 24:	learn: 0.6968470	total: 631ms	remaining: 14m 43s
# 25:	learn: 0.6965521	total: 655ms	remaining: 14m 41s
# 26:	learn: 0.6962608	total: 678ms	remaining: 14m 37s
# 27:	learn: 0.6959743	total: 700ms	remaining: 14m 33s
# 28:	learn: 0.6956897	total: 725ms	remaining: 14m 33s
# 29:	learn: 0.6954128	total: 747ms	remaining: 14m 30s
# 30:	learn: 0.6951318	total: 769ms	remaining: 14m 27s
# 31:	learn: 0.6948556	total: 795ms	remaining: 14m 28s
# 32:	learn: 0.6945811	total: 818ms	remaining: 14m 26s
# 33:	learn: 0.6943071	total: 845ms	remaining: 14m 28s
# 34:	learn: 0.6940395	total: 868ms	remaining: 14m 26s
# 35:	learn: 0.6937730	total: 893ms	remaining: 14m 27s
# 36:	learn: 0.6935102	total: 916ms	remaining: 14m 25s
# 37:	learn: 0.6932516	total: 942ms	remaining: 14m 26s
# 38:	learn: 0.6929916	total: 965ms	remaining: 14m 25s
# 39:	learn: 0.6927344	total: 991ms	remaining: 14m 26s
# 40:	learn: 0.6924818	total: 1.01s	remaining: 14m 25s
# 41:	learn: 0.6922342	total: 1.04s	remaining: 14m 26s
# 42:	learn: 0.6919857	total: 1.06s	remaining: 14m 24s
# 43:	learn: 0.6917385	total: 1.09s	remaining: 14m 24s
# 44:	learn: 0.6914987	total: 1.11s	remaining: 14m 22s
# 45:	learn: 0.6912559	total: 1.13s	remaining: 14m 21s
# 46:	learn: 0.6910176	total: 1.16s	remaining: 14m 21s
# 47:	learn: 0.6907794	total: 1.18s	remaining: 14m 22s
# 48:	learn: 0.6905448	total: 1.21s	remaining: 14m 20s
# 49:	learn: 0.6903110	total: 1.23s	remaining: 14m 19s
# 50:	learn: 0.6900844	total: 1.25s	remaining: 14m 19s
# 51:	learn: 0.6898579	total: 1.28s	remaining: 14m 18s
# 52:	learn: 0.6896311	total: 1.3s	remaining: 14m 19s
# 53:	learn: 0.6894073	total: 1.32s	remaining: 14m 17s
# 54:	learn: 0.6891853	total: 1.35s	remaining: 14m 18s
# 55:	learn: 0.6889748	total: 1.37s	remaining: 14m 17s
# 56:	learn: 0.6887654	total: 1.39s	remaining: 14m 15s
# 57:	learn: 0.6885527	total: 1.42s	remaining: 14m 14s
# 58:	learn: 0.6883403	total: 1.44s	remaining: 14m 14s
# 59:	learn: 0.6881319	total: 1.47s	remaining: 14m 15s
# 60:	learn: 0.6879280	total: 1.49s	remaining: 14m 15s
# 61:	learn: 0.6877214	total: 1.52s	remaining: 14m 14s
# 62:	learn: 0.6875259	total: 1.54s	remaining: 14m 14s
# 63:	learn: 0.6873222	total: 1.57s	remaining: 14m 15s
# 64:	learn: 0.6871233	total: 1.59s	remaining: 14m 14s
# 65:	learn: 0.6869367	total: 1.61s	remaining: 14m 14s
# 66:	learn: 0.6867408	total: 1.64s	remaining: 14m 14s
# 67:	learn: 0.6865433	total: 1.67s	remaining: 14m 15s
# 68:	learn: 0.6863583	total: 1.69s	remaining: 14m 14s
# 69:	learn: 0.6861657	total: 1.71s	remaining: 14m 14s
# 70:	learn: 0.6859714	total: 1.74s	remaining: 14m 13s
# 71:	learn: 0.6857819	total: 1.76s	remaining: 14m 12s
# 72:	learn: 0.6856040	total: 1.78s	remaining: 14m 12s
# 73:	learn: 0.6854213	total: 1.8s	remaining: 14m 11s
# 74:	learn: 0.6852480	total: 1.83s	remaining: 14m 11s
# 75:	learn: 0.6850641	total: 1.85s	remaining: 14m 11s
# 76:	learn: 0.6848838	total: 1.88s	remaining: 14m 12s
# 77:	learn: 0.6847055	total: 1.9s	remaining: 14m 11s
# 78:	learn: 0.6845322	total: 1.93s	remaining: 14m 13s
# 79:	learn: 0.6843592	total: 1.95s	remaining: 14m 12s
# 80:	learn: 0.6841846	total: 1.98s	remaining: 14m 13s
# 81:	learn: 0.6840098	total: 2s	remaining: 14m 13s
# 82:	learn: 0.6838379	total: 2.03s	remaining: 14m 13s
# 83:	learn: 0.6836798	total: 2.05s	remaining: 14m 12s
# 84:	learn: 0.6835095	total: 2.07s	remaining: 14m 11s
# 85:	learn: 0.6833568	total: 2.1s	remaining: 14m 12s
# 86:	learn: 0.6832043	total: 2.13s	remaining: 14m 12s
# 87:	learn: 0.6830365	total: 2.15s	remaining: 14m 12s
# 88:	learn: 0.6828748	total: 2.17s	remaining: 14m 13s
# 89:	learn: 0.6827123	total: 2.2s	remaining: 14m 13s
# 90:	learn: 0.6825519	total: 2.23s	remaining: 14m 13s
# 91:	learn: 0.6823971	total: 2.25s	remaining: 14m 13s
# 92:	learn: 0.6822526	total: 2.27s	remaining: 14m 13s
# 93:	learn: 0.6820956	total: 2.3s	remaining: 14m 13s
# 94:	learn: 0.6819439	total: 2.33s	remaining: 14m 17s
# 95:	learn: 0.6817941	total: 2.37s	remaining: 14m 21s
# 96:	learn: 0.6816471	total: 2.4s	remaining: 14m 22s
# 97:	learn: 0.6815106	total: 2.46s	remaining: 14m 38s
# 98:	learn: 0.6813686	total: 2.49s	remaining: 14m 39s
# 99:	learn: 0.6812264	total: 2.52s	remaining: 14m 40s
# 100:	learn: 0.6810786	total: 2.54s	remaining: 14m 39s
# 101:	learn: 0.6809395	total: 2.57s	remaining: 14m 38s
# 102:	learn: 0.6808054	total: 2.59s	remaining: 14m 38s
# 103:	learn: 0.6806612	total: 2.62s	remaining: 14m 37s
# 104:	learn: 0.6805225	total: 2.64s	remaining: 14m 37s
# 105:	learn: 0.6803799	total: 2.66s	remaining: 14m 36s
# 106:	learn: 0.6802418	total: 2.69s	remaining: 14m 36s
# 107:	learn: 0.6801092	total: 2.71s	remaining: 14m 36s
# 108:	learn: 0.6799784	total: 2.73s	remaining: 14m 35s
# 109:	learn: 0.6798492	total: 2.76s	remaining: 14m 35s
# 110:	learn: 0.6797222	total: 2.78s	remaining: 14m 34s
# 111:	learn: 0.6795924	total: 2.81s	remaining: 14m 34s
# 112:	learn: 0.6794658	total: 2.83s	remaining: 14m 33s
# 113:	learn: 0.6793400	total: 2.85s	remaining: 14m 33s
# 114:	learn: 0.6792124	total: 2.88s	remaining: 14m 33s
# 115:	learn: 0.6790925	total: 2.9s	remaining: 14m 33s
# 116:	learn: 0.6789768	total: 2.93s	remaining: 14m 33s
# 117:	learn: 0.6788520	total: 2.96s	remaining: 14m 34s
# 118:	learn: 0.6787274	total: 2.98s	remaining: 14m 33s
# 119:	learn: 0.6786161	total: 3s	remaining: 14m 33s
# 120:	learn: 0.6784964	total: 3.03s	remaining: 14m 32s
# 121:	learn: 0.6783773	total: 3.05s	remaining: 14m 32s
# 122:	learn: 0.6782546	total: 3.08s	remaining: 14m 32s
# 123:	learn: 0.6781433	total: 3.1s	remaining: 14m 32s
# 124:	learn: 0.6780274	total: 3.13s	remaining: 14m 32s
# 125:	learn: 0.6779225	total: 3.15s	remaining: 14m 32s
# 126:	learn: 0.6778094	total: 3.17s	remaining: 14m 32s
# 127:	learn: 0.6776977	total: 3.2s	remaining: 14m 31s
# 128:	learn: 0.6775877	total: 3.22s	remaining: 14m 31s
# 129:	learn: 0.6774810	total: 3.24s	remaining: 14m 30s
# 130:	learn: 0.6773695	total: 3.27s	remaining: 14m 30s
# 131:	learn: 0.6772592	total: 3.29s	remaining: 14m 30s
# 132:	learn: 0.6771524	total: 3.32s	remaining: 14m 30s
# 133:	learn: 0.6770514	total: 3.34s	remaining: 14m 29s
# 134:	learn: 0.6769521	total: 3.37s	remaining: 14m 29s
# 135:	learn: 0.6768493	total: 3.39s	remaining: 14m 29s
# 136:	learn: 0.6767424	total: 3.42s	remaining: 14m 29s
# 137:	learn: 0.6766431	total: 3.44s	remaining: 14m 28s
# 138:	learn: 0.6765463	total: 3.46s	remaining: 14m 28s
# 139:	learn: 0.6764394	total: 3.49s	remaining: 14m 28s
# 140:	learn: 0.6763350	total: 3.51s	remaining: 14m 28s
# 141:	learn: 0.6762390	total: 3.54s	remaining: 14m 27s
# 142:	learn: 0.6761421	total: 3.56s	remaining: 14m 27s
# 143:	learn: 0.6760400	total: 3.58s	remaining: 14m 27s
# 144:	learn: 0.6759466	total: 3.6s	remaining: 14m 26s
# 145:	learn: 0.6758449	total: 3.63s	remaining: 14m 26s
# 146:	learn: 0.6757555	total: 3.65s	remaining: 14m 26s
# 147:	learn: 0.6756660	total: 3.68s	remaining: 14m 26s
# 148:	learn: 0.6755735	total: 3.7s	remaining: 14m 26s
# 149:	learn: 0.6754802	total: 3.73s	remaining: 14m 26s
# 150:	learn: 0.6753879	total: 3.75s	remaining: 14m 25s
# 151:	learn: 0.6752960	total: 3.77s	remaining: 14m 25s
# 152:	learn: 0.6752015	total: 3.8s	remaining: 14m 25s
# 153:	learn: 0.6751167	total: 3.83s	remaining: 14m 25s
# 154:	learn: 0.6750212	total: 3.85s	remaining: 14m 25s
# 155:	learn: 0.6749275	total: 3.87s	remaining: 14m 24s
# 156:	learn: 0.6748385	total: 3.9s	remaining: 14m 24s
# 157:	learn: 0.6747527	total: 3.92s	remaining: 14m 24s
# 158:	learn: 0.6746673	total: 3.94s	remaining: 14m 24s
# 159:	learn: 0.6745836	total: 3.97s	remaining: 14m 24s
# 160:	learn: 0.6745038	total: 4s	remaining: 14m 25s
# 161:	learn: 0.6744234	total: 4.04s	remaining: 14m 27s
# 162:	learn: 0.6743393	total: 4.07s	remaining: 14m 29s
# 163:	learn: 0.6742527	total: 4.1s	remaining: 14m 30s
# 164:	learn: 0.6741708	total: 4.13s	remaining: 14m 31s
# 165:	learn: 0.6740946	total: 4.15s	remaining: 14m 31s
# 166:	learn: 0.6740172	total: 4.18s	remaining: 14m 31s
# 167:	learn: 0.6739333	total: 4.2s	remaining: 14m 31s
# 168:	learn: 0.6738586	total: 4.23s	remaining: 14m 31s
# 169:	learn: 0.6737737	total: 4.26s	remaining: 14m 32s
# 170:	learn: 0.6736952	total: 4.28s	remaining: 14m 31s
# 171:	learn: 0.6736210	total: 4.31s	remaining: 14m 31s
# 172:	learn: 0.6735482	total: 4.33s	remaining: 14m 31s
# 173:	learn: 0.6734731	total: 4.36s	remaining: 14m 32s
# 174:	learn: 0.6733911	total: 4.38s	remaining: 14m 31s
# 175:	learn: 0.6733201	total: 4.41s	remaining: 14m 32s
# 176:	learn: 0.6732421	total: 4.43s	remaining: 14m 32s
# 177:	learn: 0.6731604	total: 4.46s	remaining: 14m 32s
# 178:	learn: 0.6730911	total: 4.48s	remaining: 14m 32s
# 179:	learn: 0.6730158	total: 4.51s	remaining: 14m 32s
# 180:	learn: 0.6729427	total: 4.53s	remaining: 14m 31s
# 181:	learn: 0.6728737	total: 4.56s	remaining: 14m 31s
# 182:	learn: 0.6728051	total: 4.58s	remaining: 14m 31s
# 183:	learn: 0.6727381	total: 4.61s	remaining: 14m 31s
# 184:	learn: 0.6726660	total: 4.63s	remaining: 14m 31s
# 185:	learn: 0.6725998	total: 4.66s	remaining: 14m 31s
# 186:	learn: 0.6725331	total: 4.68s	remaining: 14m 31s
# 187:	learn: 0.6724714	total: 4.71s	remaining: 14m 31s
# 188:	learn: 0.6724028	total: 4.73s	remaining: 14m 30s
# 189:	learn: 0.6723402	total: 4.75s	remaining: 14m 30s
# 190:	learn: 0.6722703	total: 4.78s	remaining: 14m 30s
# 191:	learn: 0.6722020	total: 4.8s	remaining: 14m 30s
# 192:	learn: 0.6721452	total: 4.83s	remaining: 14m 30s
# 193:	learn: 0.6720855	total: 4.85s	remaining: 14m 30s
# 194:	learn: 0.6720283	total: 4.88s	remaining: 14m 30s
# 195:	learn: 0.6719657	total: 4.9s	remaining: 14m 30s
# 196:	learn: 0.6718969	total: 4.93s	remaining: 14m 30s
# 197:	learn: 0.6718266	total: 4.95s	remaining: 14m 30s
# 198:	learn: 0.6717592	total: 4.97s	remaining: 14m 30s
# 199:	learn: 0.6716988	total: 5s	remaining: 14m 30s
# 200:	learn: 0.6716376	total: 5.02s	remaining: 14m 29s
# 201:	learn: 0.6715725	total: 5.05s	remaining: 14m 29s
# 202:	learn: 0.6715126	total: 5.07s	remaining: 14m 29s
# 203:	learn: 0.6714471	total: 5.1s	remaining: 14m 29s
# 204:	learn: 0.6713823	total: 5.12s	remaining: 14m 29s
# 205:	learn: 0.6713240	total: 5.15s	remaining: 14m 29s
# 206:	learn: 0.6712744	total: 5.17s	remaining: 14m 29s
# 207:	learn: 0.6712158	total: 5.2s	remaining: 14m 29s
# 208:	learn: 0.6711597	total: 5.22s	remaining: 14m 29s
# 209:	learn: 0.6711158	total: 5.25s	remaining: 14m 29s
# 210:	learn: 0.6710651	total: 5.27s	remaining: 14m 29s
# 211:	learn: 0.6710022	total: 5.3s	remaining: 14m 29s
# 212:	learn: 0.6709441	total: 5.32s	remaining: 14m 29s
# 213:	learn: 0.6708864	total: 5.37s	remaining: 14m 32s
# 214:	learn: 0.6708272	total: 5.39s	remaining: 14m 32s
# 215:	learn: 0.6707690	total: 5.42s	remaining: 14m 32s
# 216:	learn: 0.6707117	total: 5.45s	remaining: 14m 33s
# 217:	learn: 0.6706617	total: 5.47s	remaining: 14m 32s
# 218:	learn: 0.6706119	total: 5.49s	remaining: 14m 32s
# 219:	learn: 0.6705670	total: 5.52s	remaining: 14m 32s
# 220:	learn: 0.6705147	total: 5.55s	remaining: 14m 33s
# 221:	learn: 0.6704640	total: 5.57s	remaining: 14m 33s
# 222:	learn: 0.6704109	total: 5.6s	remaining: 14m 32s
# 223:	learn: 0.6703560	total: 5.62s	remaining: 14m 32s
# 224:	learn: 0.6702997	total: 5.65s	remaining: 14m 32s
# 225:	learn: 0.6702428	total: 5.67s	remaining: 14m 32s
# 226:	learn: 0.6702013	total: 5.7s	remaining: 14m 33s
# 227:	learn: 0.6701631	total: 5.73s	remaining: 14m 33s
# 228:	learn: 0.6701210	total: 5.75s	remaining: 14m 33s
# 229:	learn: 0.6700739	total: 5.78s	remaining: 14m 33s
# 230:	learn: 0.6700227	total: 5.8s	remaining: 14m 33s
# 231:	learn: 0.6699729	total: 5.83s	remaining: 14m 33s
# 232:	learn: 0.6699228	total: 5.85s	remaining: 14m 33s
# 233:	learn: 0.6698763	total: 5.88s	remaining: 14m 33s
# 234:	learn: 0.6698282	total: 5.91s	remaining: 14m 33s
# 235:	learn: 0.6697870	total: 5.93s	remaining: 14m 33s
# 236:	learn: 0.6697503	total: 5.96s	remaining: 14m 34s
# 237:	learn: 0.6697028	total: 5.99s	remaining: 14m 35s
# 238:	learn: 0.6696569	total: 6.02s	remaining: 14m 35s
# 239:	learn: 0.6696061	total: 6.04s	remaining: 14m 35s
# 240:	learn: 0.6695590	total: 6.07s	remaining: 14m 35s
# 241:	learn: 0.6695100	total: 6.1s	remaining: 14m 36s
# 242:	learn: 0.6694688	total: 6.13s	remaining: 14m 36s
# 243:	learn: 0.6694269	total: 6.16s	remaining: 14m 36s
# 244:	learn: 0.6693786	total: 6.18s	remaining: 14m 37s
# 245:	learn: 0.6693351	total: 6.21s	remaining: 14m 38s
# 246:	learn: 0.6692941	total: 6.24s	remaining: 14m 38s
# 247:	learn: 0.6692443	total: 6.27s	remaining: 14m 39s
# 248:	learn: 0.6692009	total: 6.3s	remaining: 14m 39s
# 249:	learn: 0.6691578	total: 6.33s	remaining: 14m 39s
# 250:	learn: 0.6691112	total: 6.36s	remaining: 14m 40s
# 251:	learn: 0.6690780	total: 6.39s	remaining: 14m 40s
# 252:	learn: 0.6690331	total: 6.42s	remaining: 14m 41s
# 253:	learn: 0.6689847	total: 6.45s	remaining: 14m 42s
# 254:	learn: 0.6689408	total: 6.48s	remaining: 14m 42s
# 255:	learn: 0.6689001	total: 6.51s	remaining: 14m 43s
# 256:	learn: 0.6688671	total: 6.54s	remaining: 14m 43s
# 257:	learn: 0.6688275	total: 6.56s	remaining: 14m 43s
# 258:	learn: 0.6687880	total: 6.59s	remaining: 14m 43s
# 259:	learn: 0.6687422	total: 6.62s	remaining: 14m 43s
# 260:	learn: 0.6687009	total: 6.64s	remaining: 14m 44s
# 261:	learn: 0.6686586	total: 6.67s	remaining: 14m 44s
# 262:	learn: 0.6686181	total: 6.7s	remaining: 14m 45s
# 263:	learn: 0.6685770	total: 6.73s	remaining: 14m 45s
# 264:	learn: 0.6685310	total: 6.76s	remaining: 14m 45s
# 265:	learn: 0.6684994	total: 6.79s	remaining: 14m 45s
# 266:	learn: 0.6684612	total: 6.81s	remaining: 14m 45s
# 267:	learn: 0.6684228	total: 6.84s	remaining: 14m 46s
# 268:	learn: 0.6683830	total: 6.86s	remaining: 14m 45s
# 269:	learn: 0.6683538	total: 6.89s	remaining: 14m 46s
# 270:	learn: 0.6683208	total: 6.92s	remaining: 14m 46s
# 271:	learn: 0.6682836	total: 6.94s	remaining: 14m 46s
# 272:	learn: 0.6682554	total: 6.97s	remaining: 14m 46s
# 273:	learn: 0.6682259	total: 7s	remaining: 14m 47s
# 274:	learn: 0.6681908	total: 7.03s	remaining: 14m 47s
# 275:	learn: 0.6681545	total: 7.05s	remaining: 14m 47s
# 276:	learn: 0.6681207	total: 7.08s	remaining: 14m 47s
# 277:	learn: 0.6680798	total: 7.11s	remaining: 14m 47s
# 278:	learn: 0.6680386	total: 7.13s	remaining: 14m 47s
# 279:	learn: 0.6679994	total: 7.16s	remaining: 14m 47s
# 280:	learn: 0.6679679	total: 7.18s	remaining: 14m 47s
# 281:	learn: 0.6679340	total: 7.21s	remaining: 14m 47s
# 282:	learn: 0.6678965	total: 7.23s	remaining: 14m 47s
# 283:	learn: 0.6678648	total: 7.25s	remaining: 14m 46s
# 284:	learn: 0.6678279	total: 7.28s	remaining: 14m 46s
# 285:	learn: 0.6678004	total: 7.3s	remaining: 14m 46s
# 286:	learn: 0.6677636	total: 7.33s	remaining: 14m 46s
# 287:	learn: 0.6677278	total: 7.35s	remaining: 14m 46s
# 288:	learn: 0.6676943	total: 7.38s	remaining: 14m 46s
# 289:	learn: 0.6676624	total: 7.4s	remaining: 14m 45s
# 290:	learn: 0.6676340	total: 7.43s	remaining: 14m 46s
# 291:	learn: 0.6675923	total: 7.46s	remaining: 14m 46s
# 292:	learn: 0.6675602	total: 7.48s	remaining: 14m 46s
# 293:	learn: 0.6675253	total: 7.5s	remaining: 14m 45s
# 294:	learn: 0.6674922	total: 7.53s	remaining: 14m 46s
# 295:	learn: 0.6674552	total: 7.55s	remaining: 14m 45s
# 296:	learn: 0.6674264	total: 7.58s	remaining: 14m 45s
# 297:	learn: 0.6674002	total: 7.61s	remaining: 14m 45s
# 298:	learn: 0.6673679	total: 7.63s	remaining: 14m 45s
# 299:	learn: 0.6673301	total: 7.66s	remaining: 14m 46s
# 300:	learn: 0.6672968	total: 7.69s	remaining: 14m 46s
# 301:	learn: 0.6672630	total: 7.71s	remaining: 14m 46s
# 302:	learn: 0.6672291	total: 7.73s	remaining: 14m 45s
# 303:	learn: 0.6672053	total: 7.76s	remaining: 14m 45s
# 304:	learn: 0.6671718	total: 7.78s	remaining: 14m 45s
# 305:	learn: 0.6671390	total: 7.81s	remaining: 14m 45s
# 306:	learn: 0.6671152	total: 7.83s	remaining: 14m 45s
# 307:	learn: 0.6670840	total: 7.86s	remaining: 14m 45s
# 308:	learn: 0.6670480	total: 7.88s	remaining: 14m 45s
# 309:	learn: 0.6670194	total: 7.91s	remaining: 14m 45s
# 310:	learn: 0.6669850	total: 7.93s	remaining: 14m 44s
# 311:	learn: 0.6669541	total: 7.96s	remaining: 14m 44s
# 312:	learn: 0.6669183	total: 7.98s	remaining: 14m 44s
# 313:	learn: 0.6668893	total: 8.01s	remaining: 14m 44s
# 314:	learn: 0.6668649	total: 8.03s	remaining: 14m 44s
# 315:	learn: 0.6668348	total: 8.06s	remaining: 14m 44s
# 316:	learn: 0.6668069	total: 8.08s	remaining: 14m 44s
# 317:	learn: 0.6667772	total: 8.11s	remaining: 14m 44s
# 318:	learn: 0.6667474	total: 8.13s	remaining: 14m 44s
# 319:	learn: 0.6667251	total: 8.16s	remaining: 14m 44s
# 320:	learn: 0.6667029	total: 8.18s	remaining: 14m 43s
# 321:	learn: 0.6666787	total: 8.21s	remaining: 14m 44s
# 322:	learn: 0.6666499	total: 8.23s	remaining: 14m 43s
# 323:	learn: 0.6666244	total: 8.26s	remaining: 14m 43s
# 324:	learn: 0.6665988	total: 8.29s	remaining: 14m 44s
# 325:	learn: 0.6665690	total: 8.31s	remaining: 14m 44s
# 326:	learn: 0.6665470	total: 8.34s	remaining: 14m 44s
# 327:	learn: 0.6665264	total: 8.37s	remaining: 14m 44s
# 328:	learn: 0.6664976	total: 8.39s	remaining: 14m 44s
# 329:	learn: 0.6664768	total: 8.42s	remaining: 14m 44s
# 330:	learn: 0.6664519	total: 8.44s	remaining: 14m 44s
# 331:	learn: 0.6664169	total: 8.47s	remaining: 14m 44s
# 332:	learn: 0.6663887	total: 8.49s	remaining: 14m 43s
# 333:	learn: 0.6663556	total: 8.52s	remaining: 14m 44s
# 334:	learn: 0.6663290	total: 8.54s	remaining: 14m 43s
# 335:	learn: 0.6662989	total: 8.57s	remaining: 14m 43s
# 336:	learn: 0.6662757	total: 8.59s	remaining: 14m 43s
# 337:	learn: 0.6662519	total: 8.62s	remaining: 14m 43s
# 338:	learn: 0.6662254	total: 8.64s	remaining: 14m 43s
# 339:	learn: 0.6661975	total: 8.67s	remaining: 14m 43s
# 340:	learn: 0.6661718	total: 8.69s	remaining: 14m 43s
# 341:	learn: 0.6661477	total: 8.72s	remaining: 14m 43s
# 342:	learn: 0.6661191	total: 8.74s	remaining: 14m 43s
# 343:	learn: 0.6660966	total: 8.77s	remaining: 14m 43s
# 344:	learn: 0.6660712	total: 8.79s	remaining: 14m 43s
# 345:	learn: 0.6660524	total: 8.82s	remaining: 14m 43s
# 346:	learn: 0.6660228	total: 8.84s	remaining: 14m 42s
# 347:	learn: 0.6659998	total: 8.87s	remaining: 14m 43s
# 348:	learn: 0.6659750	total: 8.89s	remaining: 14m 42s
# 349:	learn: 0.6659531	total: 8.92s	remaining: 14m 42s
# 350:	learn: 0.6659327	total: 8.94s	remaining: 14m 42s
# 351:	learn: 0.6659125	total: 8.97s	remaining: 14m 43s
# 352:	learn: 0.6658908	total: 9s	remaining: 14m 43s
# 353:	learn: 0.6658659	total: 9.02s	remaining: 14m 42s
# 354:	learn: 0.6658466	total: 9.04s	remaining: 14m 42s
# 355:	learn: 0.6658233	total: 9.07s	remaining: 14m 42s
# 356:	learn: 0.6658038	total: 9.1s	remaining: 14m 42s
# 357:	learn: 0.6657758	total: 9.12s	remaining: 14m 42s
# 358:	learn: 0.6657523	total: 9.14s	remaining: 14m 42s
# 359:	learn: 0.6657339	total: 9.16s	remaining: 14m 41s
# 360:	learn: 0.6657124	total: 9.19s	remaining: 14m 41s
# 361:	learn: 0.6656975	total: 9.21s	remaining: 14m 41s
# 362:	learn: 0.6656791	total: 9.24s	remaining: 14m 41s
# 363:	learn: 0.6656558	total: 9.27s	remaining: 14m 41s
# 364:	learn: 0.6656375	total: 9.29s	remaining: 14m 41s
# 365:	learn: 0.6656174	total: 9.32s	remaining: 14m 41s
# 366:	learn: 0.6655945	total: 9.34s	remaining: 14m 41s
# 367:	learn: 0.6655695	total: 9.37s	remaining: 14m 41s
# 368:	learn: 0.6655463	total: 9.4s	remaining: 14m 42s
# 369:	learn: 0.6655260	total: 9.42s	remaining: 14m 41s
# 370:	learn: 0.6655058	total: 9.45s	remaining: 14m 41s
# 371:	learn: 0.6654908	total: 9.47s	remaining: 14m 41s
# 372:	learn: 0.6654743	total: 9.49s	remaining: 14m 41s
# 373:	learn: 0.6654479	total: 9.52s	remaining: 14m 41s
# 374:	learn: 0.6654272	total: 9.54s	remaining: 14m 41s
# 375:	learn: 0.6654076	total: 9.57s	remaining: 14m 41s
# 376:	learn: 0.6653900	total: 9.6s	remaining: 14m 41s
# 377:	learn: 0.6653728	total: 9.62s	remaining: 14m 40s
# 378:	learn: 0.6653553	total: 9.64s	remaining: 14m 40s
# 379:	learn: 0.6653335	total: 9.67s	remaining: 14m 40s
# 380:	learn: 0.6653171	total: 9.7s	remaining: 14m 40s
# 381:	learn: 0.6652948	total: 9.72s	remaining: 14m 40s
# 382:	learn: 0.6652762	total: 9.74s	remaining: 14m 40s
# 383:	learn: 0.6652555	total: 9.76s	remaining: 14m 40s
# 384:	learn: 0.6652387	total: 9.79s	remaining: 14m 40s
# 385:	learn: 0.6652201	total: 9.81s	remaining: 14m 40s
# 386:	learn: 0.6651996	total: 9.84s	remaining: 14m 40s
# 387:	learn: 0.6651803	total: 9.87s	remaining: 14m 40s
# 388:	learn: 0.6651678	total: 9.9s	remaining: 14m 40s
# 389:	learn: 0.6651485	total: 9.93s	remaining: 14m 40s
# 390:	learn: 0.6651276	total: 9.95s	remaining: 14m 40s
# 391:	learn: 0.6651083	total: 9.97s	remaining: 14m 40s
# 392:	learn: 0.6650910	total: 10s	remaining: 14m 40s
# 393:	learn: 0.6650719	total: 10s	remaining: 14m 40s
# 394:	learn: 0.6650510	total: 10.1s	remaining: 14m 40s
# 395:	learn: 0.6650306	total: 10.1s	remaining: 14m 40s
# 396:	learn: 0.6650137	total: 10.1s	remaining: 14m 40s
# 397:	learn: 0.6649941	total: 10.1s	remaining: 14m 40s
# 398:	learn: 0.6649741	total: 10.2s	remaining: 14m 41s
# 399:	learn: 0.6649534	total: 10.2s	remaining: 14m 41s
# 400:	learn: 0.6649388	total: 10.2s	remaining: 14m 41s
# 401:	learn: 0.6649224	total: 10.2s	remaining: 14m 41s
# 402:	learn: 0.6649010	total: 10.3s	remaining: 14m 40s
# 403:	learn: 0.6648871	total: 10.3s	remaining: 14m 40s
# 404:	learn: 0.6648699	total: 10.3s	remaining: 14m 40s
# 405:	learn: 0.6648504	total: 10.3s	remaining: 14m 40s
# 406:	learn: 0.6648282	total: 10.4s	remaining: 14m 40s
# 407:	learn: 0.6648132	total: 10.4s	remaining: 14m 40s
# 408:	learn: 0.6647953	total: 10.4s	remaining: 14m 40s
# 409:	learn: 0.6647784	total: 10.4s	remaining: 14m 40s
# 410:	learn: 0.6647600	total: 10.5s	remaining: 14m 40s
# 411:	learn: 0.6647395	total: 10.5s	remaining: 14m 40s
# 412:	learn: 0.6647223	total: 10.5s	remaining: 14m 40s
# 413:	learn: 0.6647061	total: 10.5s	remaining: 14m 39s
# 414:	learn: 0.6646932	total: 10.6s	remaining: 14m 39s
# 415:	learn: 0.6646748	total: 10.6s	remaining: 14m 39s
# 416:	learn: 0.6646617	total: 10.6s	remaining: 14m 39s
# 417:	learn: 0.6646383	total: 10.6s	remaining: 14m 39s
# 418:	learn: 0.6646181	total: 10.7s	remaining: 14m 39s
# 419:	learn: 0.6645987	total: 10.7s	remaining: 14m 38s
# 420:	learn: 0.6645864	total: 10.7s	remaining: 14m 39s
# 421:	learn: 0.6645727	total: 10.7s	remaining: 14m 38s
# 422:	learn: 0.6645535	total: 10.7s	remaining: 14m 38s
# 423:	learn: 0.6645363	total: 10.8s	remaining: 14m 38s
# 424:	learn: 0.6645246	total: 10.8s	remaining: 14m 38s
# 425:	learn: 0.6645034	total: 10.8s	remaining: 14m 38s
# 426:	learn: 0.6644839	total: 10.8s	remaining: 14m 37s
# 427:	learn: 0.6644636	total: 10.9s	remaining: 14m 38s
# 428:	learn: 0.6644465	total: 10.9s	remaining: 14m 37s
# 429:	learn: 0.6644277	total: 10.9s	remaining: 14m 37s
# 430:	learn: 0.6644136	total: 10.9s	remaining: 14m 37s
# 431:	learn: 0.6644017	total: 11s	remaining: 14m 37s
# 432:	learn: 0.6643879	total: 11s	remaining: 14m 37s
# 433:	learn: 0.6643724	total: 11s	remaining: 14m 37s
# 434:	learn: 0.6643589	total: 11s	remaining: 14m 37s
# 435:	learn: 0.6643412	total: 11.1s	remaining: 14m 37s
# 436:	learn: 0.6643196	total: 11.1s	remaining: 14m 37s
# 437:	learn: 0.6642994	total: 11.1s	remaining: 14m 37s
# 438:	learn: 0.6642885	total: 11.1s	remaining: 14m 37s
# 439:	learn: 0.6642769	total: 11.2s	remaining: 14m 37s
# 440:	learn: 0.6642580	total: 11.2s	remaining: 14m 36s
# 441:	learn: 0.6642452	total: 11.2s	remaining: 14m 36s
# 442:	learn: 0.6642304	total: 11.2s	remaining: 14m 36s
# 443:	learn: 0.6642176	total: 11.3s	remaining: 14m 36s
# 444:	learn: 0.6641987	total: 11.3s	remaining: 14m 36s
# 445:	learn: 0.6641845	total: 11.3s	remaining: 14m 36s
# 446:	learn: 0.6641711	total: 11.4s	remaining: 14m 39s
# 447:	learn: 0.6641571	total: 11.4s	remaining: 14m 40s
# 448:	learn: 0.6641464	total: 11.4s	remaining: 14m 39s
# 449:	learn: 0.6641356	total: 11.5s	remaining: 14m 39s
# 450:	learn: 0.6641256	total: 11.5s	remaining: 14m 39s
# 451:	learn: 0.6641099	total: 11.5s	remaining: 14m 40s
# 452:	learn: 0.6640912	total: 11.5s	remaining: 14m 39s
# 453:	learn: 0.6640791	total: 11.6s	remaining: 14m 39s
# 454:	learn: 0.6640643	total: 11.6s	remaining: 14m 39s
# 455:	learn: 0.6640536	total: 11.6s	remaining: 14m 39s
# 456:	learn: 0.6640410	total: 11.6s	remaining: 14m 39s
# 457:	learn: 0.6640295	total: 11.7s	remaining: 14m 39s
# 458:	learn: 0.6640069	total: 11.7s	remaining: 14m 39s
# 459:	learn: 0.6639919	total: 11.7s	remaining: 14m 39s
# 460:	learn: 0.6639789	total: 11.7s	remaining: 14m 39s
# 461:	learn: 0.6639641	total: 11.8s	remaining: 14m 39s
# 462:	learn: 0.6639521	total: 11.8s	remaining: 14m 39s
# 463:	learn: 0.6639329	total: 11.8s	remaining: 14m 39s
# 464:	learn: 0.6639216	total: 11.8s	remaining: 14m 38s
# 465:	learn: 0.6639037	total: 11.9s	remaining: 14m 38s
# 466:	learn: 0.6638907	total: 11.9s	remaining: 14m 38s
# 467:	learn: 0.6638744	total: 11.9s	remaining: 14m 38s
# 468:	learn: 0.6638582	total: 11.9s	remaining: 14m 38s
# 469:	learn: 0.6638467	total: 12s	remaining: 14m 38s
# 470:	learn: 0.6638292	total: 12s	remaining: 14m 38s
# 471:	learn: 0.6638186	total: 12s	remaining: 14m 38s
# 472:	learn: 0.6637968	total: 12s	remaining: 14m 38s
# 473:	learn: 0.6637862	total: 12.1s	remaining: 14m 38s
# 474:	learn: 0.6637758	total: 12.1s	remaining: 14m 38s
# 475:	learn: 0.6637650	total: 12.1s	remaining: 14m 38s
# 476:	learn: 0.6637481	total: 12.1s	remaining: 14m 39s
# 477:	learn: 0.6637299	total: 12.2s	remaining: 14m 39s
# 478:	learn: 0.6637107	total: 12.2s	remaining: 14m 39s
# 479:	learn: 0.6636947	total: 12.2s	remaining: 14m 39s
# 480:	learn: 0.6636864	total: 12.3s	remaining: 14m 39s
# 481:	learn: 0.6636687	total: 12.3s	remaining: 14m 39s
# 482:	learn: 0.6636552	total: 12.3s	remaining: 14m 39s
# 483:	learn: 0.6636413	total: 12.3s	remaining: 14m 39s
# 484:	learn: 0.6636217	total: 12.4s	remaining: 14m 39s
# 485:	learn: 0.6636131	total: 12.4s	remaining: 14m 39s
# 486:	learn: 0.6635950	total: 12.4s	remaining: 14m 39s
# 487:	learn: 0.6635821	total: 12.4s	remaining: 14m 39s
# 488:	learn: 0.6635718	total: 12.5s	remaining: 14m 39s
# 489:	learn: 0.6635599	total: 12.5s	remaining: 14m 39s
# 490:	learn: 0.6635402	total: 12.5s	remaining: 14m 39s
# 491:	learn: 0.6635296	total: 12.5s	remaining: 14m 39s
# 492:	learn: 0.6635139	total: 12.6s	remaining: 14m 39s
# 493:	learn: 0.6634997	total: 12.6s	remaining: 14m 39s
# 494:	learn: 0.6634886	total: 12.6s	remaining: 14m 38s
# 495:	learn: 0.6634791	total: 12.6s	remaining: 14m 38s
# 496:	learn: 0.6634674	total: 12.7s	remaining: 14m 38s
# 497:	learn: 0.6634556	total: 12.7s	remaining: 14m 38s
# 498:	learn: 0.6634453	total: 12.7s	remaining: 14m 38s
# 499:	learn: 0.6634284	total: 12.7s	remaining: 14m 38s
# 500:	learn: 0.6634152	total: 12.8s	remaining: 14m 38s
# 501:	learn: 0.6633995	total: 12.8s	remaining: 14m 37s
# 502:	learn: 0.6633893	total: 12.8s	remaining: 14m 38s
# 503:	learn: 0.6633812	total: 12.8s	remaining: 14m 37s
# 504:	learn: 0.6633700	total: 12.8s	remaining: 14m 37s
# 505:	learn: 0.6633518	total: 12.9s	remaining: 14m 37s
# 506:	learn: 0.6633396	total: 12.9s	remaining: 14m 37s
# 507:	learn: 0.6633243	total: 12.9s	remaining: 14m 37s
# 508:	learn: 0.6633116	total: 12.9s	remaining: 14m 37s
# 509:	learn: 0.6633022	total: 13s	remaining: 14m 36s
# 510:	learn: 0.6632928	total: 13s	remaining: 14m 36s
# 511:	learn: 0.6632802	total: 13s	remaining: 14m 36s
# 512:	learn: 0.6632690	total: 13s	remaining: 14m 36s
# 513:	learn: 0.6632569	total: 13.1s	remaining: 14m 36s
# 514:	learn: 0.6632467	total: 13.1s	remaining: 14m 36s
# 515:	learn: 0.6632287	total: 13.1s	remaining: 14m 36s
# 516:	learn: 0.6632208	total: 13.1s	remaining: 14m 36s
# 517:	learn: 0.6632090	total: 13.2s	remaining: 14m 36s
# 518:	learn: 0.6631943	total: 13.2s	remaining: 14m 36s
# 519:	learn: 0.6631802	total: 13.2s	remaining: 14m 36s
# 520:	learn: 0.6631729	total: 13.2s	remaining: 14m 36s
# 521:	learn: 0.6631602	total: 13.3s	remaining: 14m 36s
# 522:	learn: 0.6631494	total: 13.3s	remaining: 14m 36s
# 523:	learn: 0.6631375	total: 13.3s	remaining: 14m 35s
# 524:	learn: 0.6631210	total: 13.3s	remaining: 14m 35s
# 525:	learn: 0.6631138	total: 13.4s	remaining: 14m 35s
# 526:	learn: 0.6631021	total: 13.4s	remaining: 14m 35s
# 527:	learn: 0.6630926	total: 13.4s	remaining: 14m 35s
# 528:	learn: 0.6630795	total: 13.4s	remaining: 14m 35s
# 529:	learn: 0.6630649	total: 13.5s	remaining: 14m 35s
# 530:	learn: 0.6630546	total: 13.5s	remaining: 14m 35s
# 531:	learn: 0.6630414	total: 13.5s	remaining: 14m 35s
# 532:	learn: 0.6630319	total: 13.5s	remaining: 14m 35s
# 533:	learn: 0.6630193	total: 13.6s	remaining: 14m 35s
# 534:	learn: 0.6630115	total: 13.6s	remaining: 14m 35s
# 535:	learn: 0.6629933	total: 13.6s	remaining: 14m 34s
# 536:	learn: 0.6629793	total: 13.6s	remaining: 14m 34s
# 537:	learn: 0.6629658	total: 13.7s	remaining: 14m 34s
# 538:	learn: 0.6629563	total: 13.7s	remaining: 14m 34s
# 539:	learn: 0.6629457	total: 13.7s	remaining: 14m 34s
# 540:	learn: 0.6629321	total: 13.7s	remaining: 14m 34s
# 541:	learn: 0.6629216	total: 13.8s	remaining: 14m 34s
# 542:	learn: 0.6629128	total: 13.8s	remaining: 14m 34s
# 543:	learn: 0.6629019	total: 13.8s	remaining: 14m 34s
# 544:	learn: 0.6628935	total: 13.8s	remaining: 14m 34s
# 545:	learn: 0.6628782	total: 13.8s	remaining: 14m 33s
# 546:	learn: 0.6628658	total: 13.9s	remaining: 14m 33s
# 547:	learn: 0.6628579	total: 13.9s	remaining: 14m 33s
# 548:	learn: 0.6628431	total: 13.9s	remaining: 14m 33s
# 549:	learn: 0.6628367	total: 13.9s	remaining: 14m 33s
# 550:	learn: 0.6628209	total: 14s	remaining: 14m 33s
# 551:	learn: 0.6628055	total: 14s	remaining: 14m 32s
# 552:	learn: 0.6627928	total: 14s	remaining: 14m 32s
# 553:	learn: 0.6627786	total: 14s	remaining: 14m 32s
# 554:	learn: 0.6627711	total: 14.1s	remaining: 14m 32s
# 555:	learn: 0.6627633	total: 14.1s	remaining: 14m 32s
# 556:	learn: 0.6627550	total: 14.1s	remaining: 14m 32s
# 557:	learn: 0.6627447	total: 14.1s	remaining: 14m 32s
# 558:	learn: 0.6627280	total: 14.2s	remaining: 14m 32s
# 559:	learn: 0.6627196	total: 14.2s	remaining: 14m 32s
# 560:	learn: 0.6627098	total: 14.2s	remaining: 14m 32s
# 561:	learn: 0.6626944	total: 14.2s	remaining: 14m 32s
# 562:	learn: 0.6626857	total: 14.3s	remaining: 14m 32s
# 563:	learn: 0.6626754	total: 14.3s	remaining: 14m 32s
# 564:	learn: 0.6626615	total: 14.3s	remaining: 14m 32s
# 565:	learn: 0.6626474	total: 14.3s	remaining: 14m 32s
# 566:	learn: 0.6626315	total: 14.4s	remaining: 14m 32s
# 567:	learn: 0.6626169	total: 14.4s	remaining: 14m 32s
# 568:	learn: 0.6626088	total: 14.4s	remaining: 14m 32s
# 569:	learn: 0.6625988	total: 14.4s	remaining: 14m 32s
# 570:	learn: 0.6625889	total: 14.5s	remaining: 14m 32s
# 571:	learn: 0.6625767	total: 14.5s	remaining: 14m 32s
# 572:	learn: 0.6625639	total: 14.5s	remaining: 14m 32s
# 573:	learn: 0.6625518	total: 14.5s	remaining: 14m 31s
# 574:	learn: 0.6625444	total: 14.6s	remaining: 14m 32s
# 575:	learn: 0.6625353	total: 14.6s	remaining: 14m 31s
# 576:	learn: 0.6625237	total: 14.6s	remaining: 14m 31s
# 577:	learn: 0.6625082	total: 14.6s	remaining: 14m 31s
# 578:	learn: 0.6625001	total: 14.7s	remaining: 14m 31s
# 579:	learn: 0.6624885	total: 14.7s	remaining: 14m 31s
# 580:	learn: 0.6624805	total: 14.7s	remaining: 14m 31s
# 581:	learn: 0.6624706	total: 14.7s	remaining: 14m 31s
# 582:	learn: 0.6624620	total: 14.8s	remaining: 14m 31s
# 583:	learn: 0.6624518	total: 14.8s	remaining: 14m 31s
# 584:	learn: 0.6624427	total: 14.8s	remaining: 14m 31s
# 585:	learn: 0.6624351	total: 14.8s	remaining: 14m 31s
# 586:	learn: 0.6624228	total: 14.9s	remaining: 14m 31s
# 587:	learn: 0.6624159	total: 14.9s	remaining: 14m 31s
# 588:	learn: 0.6624045	total: 14.9s	remaining: 14m 31s
# 589:	learn: 0.6623961	total: 14.9s	remaining: 14m 31s
# 590:	learn: 0.6623883	total: 15s	remaining: 14m 31s
# 591:	learn: 0.6623748	total: 15s	remaining: 14m 31s
# 592:	learn: 0.6623640	total: 15s	remaining: 14m 31s
# 593:	learn: 0.6623522	total: 15s	remaining: 14m 30s
# 594:	learn: 0.6623426	total: 15.1s	remaining: 14m 30s
# 595:	learn: 0.6623327	total: 15.1s	remaining: 14m 30s
# 596:	learn: 0.6623261	total: 15.1s	remaining: 14m 31s
# 597:	learn: 0.6623191	total: 15.1s	remaining: 14m 31s
# 598:	learn: 0.6623150	total: 15.2s	remaining: 14m 30s
# 599:	learn: 0.6623046	total: 15.2s	remaining: 14m 30s
# 600:	learn: 0.6622960	total: 15.2s	remaining: 14m 30s
# 601:	learn: 0.6622853	total: 15.2s	remaining: 14m 30s
# 602:	learn: 0.6622791	total: 15.3s	remaining: 14m 30s
# 603:	learn: 0.6622652	total: 15.3s	remaining: 14m 30s
# 604:	learn: 0.6622513	total: 15.3s	remaining: 14m 30s
# 605:	learn: 0.6622429	total: 15.3s	remaining: 14m 30s
# 606:	learn: 0.6622362	total: 15.4s	remaining: 14m 30s
# 607:	learn: 0.6622243	total: 15.4s	remaining: 14m 30s
# 608:	learn: 0.6622113	total: 15.4s	remaining: 14m 30s
# 609:	learn: 0.6622028	total: 15.4s	remaining: 14m 30s
# 610:	learn: 0.6621962	total: 15.5s	remaining: 14m 30s
# 611:	learn: 0.6621870	total: 15.5s	remaining: 14m 30s
# 612:	learn: 0.6621753	total: 15.5s	remaining: 14m 30s
# 613:	learn: 0.6621683	total: 15.5s	remaining: 14m 30s
# 614:	learn: 0.6621607	total: 15.6s	remaining: 14m 30s
# 615:	learn: 0.6621527	total: 15.6s	remaining: 14m 30s
# 616:	learn: 0.6621424	total: 15.6s	remaining: 14m 30s
# 617:	learn: 0.6621356	total: 15.6s	remaining: 14m 30s
# 618:	learn: 0.6621263	total: 15.7s	remaining: 14m 30s
# 619:	learn: 0.6621193	total: 15.7s	remaining: 14m 29s
# 620:	learn: 0.6621097	total: 15.7s	remaining: 14m 29s
# 621:	learn: 0.6621004	total: 15.7s	remaining: 14m 29s
# 622:	learn: 0.6620903	total: 15.8s	remaining: 14m 29s
# 623:	learn: 0.6620796	total: 15.8s	remaining: 14m 29s
# 624:	learn: 0.6620648	total: 15.8s	remaining: 14m 29s
# 625:	learn: 0.6620520	total: 15.8s	remaining: 14m 29s
# 626:	learn: 0.6620400	total: 15.9s	remaining: 14m 30s
# 627:	learn: 0.6620313	total: 15.9s	remaining: 14m 29s
# 628:	learn: 0.6620191	total: 15.9s	remaining: 14m 29s
# 629:	learn: 0.6620123	total: 15.9s	remaining: 14m 29s
# 630:	learn: 0.6620018	total: 16s	remaining: 14m 29s
# 631:	learn: 0.6619937	total: 16s	remaining: 14m 29s
# 632:	learn: 0.6619867	total: 16s	remaining: 14m 29s
# 633:	learn: 0.6619786	total: 16s	remaining: 14m 29s
# 634:	learn: 0.6619722	total: 16.1s	remaining: 14m 30s
# 635:	learn: 0.6619617	total: 16.1s	remaining: 14m 30s
# 636:	learn: 0.6619531	total: 16.1s	remaining: 14m 30s
# 637:	learn: 0.6619451	total: 16.2s	remaining: 14m 30s
# 638:	learn: 0.6619318	total: 16.2s	remaining: 14m 30s
# 639:	learn: 0.6619275	total: 16.2s	remaining: 14m 30s
# 640:	learn: 0.6619191	total: 16.2s	remaining: 14m 30s
# 641:	learn: 0.6619117	total: 16.3s	remaining: 14m 30s
# 642:	learn: 0.6619019	total: 16.3s	remaining: 14m 29s
# 643:	learn: 0.6618954	total: 16.3s	remaining: 14m 29s
# 644:	learn: 0.6618879	total: 16.3s	remaining: 14m 30s
# 645:	learn: 0.6618811	total: 16.4s	remaining: 14m 30s
# 646:	learn: 0.6618689	total: 16.4s	remaining: 14m 29s
# 647:	learn: 0.6618600	total: 16.4s	remaining: 14m 29s
# 648:	learn: 0.6618515	total: 16.4s	remaining: 14m 29s
# 649:	learn: 0.6618404	total: 16.5s	remaining: 14m 29s
# 650:	learn: 0.6618298	total: 16.5s	remaining: 14m 29s
# 651:	learn: 0.6618241	total: 16.5s	remaining: 14m 29s
# 652:	learn: 0.6618191	total: 16.5s	remaining: 14m 29s
# 653:	learn: 0.6618075	total: 16.6s	remaining: 14m 29s
# 654:	learn: 0.6618012	total: 16.6s	remaining: 14m 29s
# 655:	learn: 0.6617905	total: 16.6s	remaining: 14m 29s
# 656:	learn: 0.6617809	total: 16.6s	remaining: 14m 29s
# 657:	learn: 0.6617709	total: 16.7s	remaining: 14m 29s
# 658:	learn: 0.6617589	total: 16.7s	remaining: 14m 29s
# 659:	learn: 0.6617483	total: 16.7s	remaining: 14m 29s
# 660:	learn: 0.6617389	total: 16.7s	remaining: 14m 29s
# 661:	learn: 0.6617314	total: 16.8s	remaining: 14m 29s
# 662:	learn: 0.6617191	total: 16.8s	remaining: 14m 28s
# 663:	learn: 0.6617099	total: 16.8s	remaining: 14m 28s
# 664:	learn: 0.6617049	total: 16.8s	remaining: 14m 28s
# 665:	learn: 0.6616980	total: 16.9s	remaining: 14m 28s
# 666:	learn: 0.6616898	total: 16.9s	remaining: 14m 28s
# 667:	learn: 0.6616834	total: 16.9s	remaining: 14m 28s
# 668:	learn: 0.6616733	total: 16.9s	remaining: 14m 28s
# 669:	learn: 0.6616665	total: 17s	remaining: 14m 28s
# 670:	learn: 0.6616592	total: 17s	remaining: 14m 28s
# 671:	learn: 0.6616517	total: 17s	remaining: 14m 28s
# 672:	learn: 0.6616457	total: 17s	remaining: 14m 28s
# 673:	learn: 0.6616345	total: 17.1s	remaining: 14m 28s
# 674:	learn: 0.6616275	total: 17.1s	remaining: 14m 28s
# 675:	learn: 0.6616217	total: 17.1s	remaining: 14m 28s
# 676:	learn: 0.6616113	total: 17.1s	remaining: 14m 28s
# 677:	learn: 0.6616063	total: 17.1s	remaining: 14m 28s
# 678:	learn: 0.6615921	total: 17.2s	remaining: 14m 27s
# 679:	learn: 0.6615823	total: 17.2s	remaining: 14m 27s
# 680:	learn: 0.6615714	total: 17.2s	remaining: 14m 27s
# 681:	learn: 0.6615651	total: 17.2s	remaining: 14m 27s
# 682:	learn: 0.6615588	total: 17.3s	remaining: 14m 27s
# 683:	learn: 0.6615529	total: 17.3s	remaining: 14m 28s
# 684:	learn: 0.6615443	total: 17.3s	remaining: 14m 28s
# 685:	learn: 0.6615370	total: 17.4s	remaining: 14m 28s
# 686:	learn: 0.6615258	total: 17.4s	remaining: 14m 28s
# 687:	learn: 0.6615165	total: 17.4s	remaining: 14m 28s
# 688:	learn: 0.6615044	total: 17.4s	remaining: 14m 28s
# 689:	learn: 0.6614946	total: 17.5s	remaining: 14m 28s
# 690:	learn: 0.6614884	total: 17.5s	remaining: 14m 28s
# 691:	learn: 0.6614827	total: 17.5s	remaining: 14m 28s
# 692:	learn: 0.6614750	total: 17.5s	remaining: 14m 28s
# 693:	learn: 0.6614662	total: 17.6s	remaining: 14m 28s
# 694:	learn: 0.6614603	total: 17.6s	remaining: 14m 28s
# 695:	learn: 0.6614491	total: 17.6s	remaining: 14m 28s
# 696:	learn: 0.6614377	total: 17.6s	remaining: 14m 28s
# 697:	learn: 0.6614268	total: 17.7s	remaining: 14m 27s
# 698:	learn: 0.6614211	total: 17.7s	remaining: 14m 27s
# 699:	learn: 0.6614146	total: 17.7s	remaining: 14m 27s
# 700:	learn: 0.6614072	total: 17.7s	remaining: 14m 27s
# 701:	learn: 0.6614002	total: 17.8s	remaining: 14m 27s
# 702:	learn: 0.6613950	total: 17.8s	remaining: 14m 27s
# 703:	learn: 0.6613862	total: 17.8s	remaining: 14m 27s
# 704:	learn: 0.6613793	total: 17.8s	remaining: 14m 28s
# 705:	learn: 0.6613739	total: 17.9s	remaining: 14m 28s
# 706:	learn: 0.6613683	total: 17.9s	remaining: 14m 27s
# 707:	learn: 0.6613631	total: 17.9s	remaining: 14m 27s
# 708:	learn: 0.6613575	total: 17.9s	remaining: 14m 28s
# 709:	learn: 0.6613498	total: 18s	remaining: 14m 28s
# 710:	learn: 0.6613365	total: 18s	remaining: 14m 28s
# 711:	learn: 0.6613263	total: 18s	remaining: 14m 28s
# 712:	learn: 0.6613163	total: 18.1s	remaining: 14m 28s
# 713:	learn: 0.6613069	total: 18.1s	remaining: 14m 28s
# 714:	learn: 0.6612981	total: 18.1s	remaining: 14m 28s
# 715:	learn: 0.6612879	total: 18.1s	remaining: 14m 28s
# 716:	learn: 0.6612822	total: 18.2s	remaining: 14m 28s
# 717:	learn: 0.6612741	total: 18.2s	remaining: 14m 28s
# 718:	learn: 0.6612636	total: 18.2s	remaining: 14m 28s
# 719:	learn: 0.6612566	total: 18.2s	remaining: 14m 28s
# 720:	learn: 0.6612491	total: 18.3s	remaining: 14m 28s
# 721:	learn: 0.6612443	total: 18.3s	remaining: 14m 29s
# 722:	learn: 0.6612380	total: 18.3s	remaining: 14m 29s
# 723:	learn: 0.6612333	total: 18.4s	remaining: 14m 29s
# 724:	learn: 0.6612289	total: 18.4s	remaining: 14m 29s
# 725:	learn: 0.6612204	total: 18.4s	remaining: 14m 29s
# 726:	learn: 0.6612140	total: 18.4s	remaining: 14m 29s
# 727:	learn: 0.6612057	total: 18.5s	remaining: 14m 29s
# 728:	learn: 0.6611993	total: 18.5s	remaining: 14m 29s
# 729:	learn: 0.6611909	total: 18.5s	remaining: 14m 29s
# 730:	learn: 0.6611820	total: 18.6s	remaining: 14m 30s
# 731:	learn: 0.6611743	total: 18.6s	remaining: 14m 30s
# 732:	learn: 0.6611677	total: 18.6s	remaining: 14m 30s
# 733:	learn: 0.6611588	total: 18.6s	remaining: 14m 30s
# 734:	learn: 0.6611514	total: 18.7s	remaining: 14m 30s
# 735:	learn: 0.6611412	total: 18.7s	remaining: 14m 30s
# 736:	learn: 0.6611341	total: 18.7s	remaining: 14m 30s
# 737:	learn: 0.6611245	total: 18.8s	remaining: 14m 30s
# 738:	learn: 0.6611159	total: 18.8s	remaining: 14m 30s
# 739:	learn: 0.6611102	total: 18.8s	remaining: 14m 30s
# 740:	learn: 0.6611039	total: 18.8s	remaining: 14m 30s
# 741:	learn: 0.6610967	total: 18.9s	remaining: 14m 30s
# 742:	learn: 0.6610859	total: 18.9s	remaining: 14m 30s
# 743:	learn: 0.6610747	total: 18.9s	remaining: 14m 30s
# 744:	learn: 0.6610661	total: 18.9s	remaining: 14m 30s
# 745:	learn: 0.6610591	total: 19s	remaining: 14m 31s
# 746:	learn: 0.6610504	total: 19s	remaining: 14m 31s
# 747:	learn: 0.6610452	total: 19s	remaining: 14m 31s
# 748:	learn: 0.6610388	total: 19.1s	remaining: 14m 31s
# 749:	learn: 0.6610325	total: 19.1s	remaining: 14m 31s
# 750:	learn: 0.6610211	total: 19.1s	remaining: 14m 31s
# 751:	learn: 0.6610113	total: 19.1s	remaining: 14m 31s
# 752:	learn: 0.6610049	total: 19.2s	remaining: 14m 31s
# 753:	learn: 0.6609969	total: 19.2s	remaining: 14m 31s
# 754:	learn: 0.6609911	total: 19.2s	remaining: 14m 31s
# 755:	learn: 0.6609848	total: 19.2s	remaining: 14m 31s
# 756:	learn: 0.6609739	total: 19.3s	remaining: 14m 31s
# 757:	learn: 0.6609678	total: 19.3s	remaining: 14m 31s
# 758:	learn: 0.6609608	total: 19.3s	remaining: 14m 32s
# 759:	learn: 0.6609545	total: 19.4s	remaining: 14m 32s
# 760:	learn: 0.6609474	total: 19.4s	remaining: 14m 32s
# 761:	learn: 0.6609407	total: 19.4s	remaining: 14m 32s
# 762:	learn: 0.6609353	total: 19.4s	remaining: 14m 32s
# 763:	learn: 0.6609286	total: 19.5s	remaining: 14m 32s
# 764:	learn: 0.6609217	total: 19.5s	remaining: 14m 32s
# 765:	learn: 0.6609129	total: 19.5s	remaining: 14m 32s
# 766:	learn: 0.6609077	total: 19.6s	remaining: 14m 32s
# 767:	learn: 0.6608989	total: 19.6s	remaining: 14m 32s
# 768:	learn: 0.6608919	total: 19.6s	remaining: 14m 33s
# 769:	learn: 0.6608837	total: 19.6s	remaining: 14m 33s
# 770:	learn: 0.6608764	total: 19.7s	remaining: 14m 33s
# 771:	learn: 0.6608720	total: 19.7s	remaining: 14m 33s
# 772:	learn: 0.6608629	total: 19.7s	remaining: 14m 33s
# 773:	learn: 0.6608597	total: 19.7s	remaining: 14m 33s
# 774:	learn: 0.6608566	total: 19.8s	remaining: 14m 33s
# 775:	learn: 0.6608487	total: 19.8s	remaining: 14m 33s
# 776:	learn: 0.6608425	total: 19.8s	remaining: 14m 33s
# 777:	learn: 0.6608366	total: 19.9s	remaining: 14m 33s
# 778:	learn: 0.6608267	total: 19.9s	remaining: 14m 33s
# 779:	learn: 0.6608202	total: 19.9s	remaining: 14m 34s
# 780:	learn: 0.6608152	total: 20s	remaining: 14m 34s
# 781:	learn: 0.6608095	total: 20s	remaining: 14m 34s
# 782:	learn: 0.6608039	total: 20s	remaining: 14m 34s
# 783:	learn: 0.6607992	total: 20s	remaining: 14m 35s
# 784:	learn: 0.6607871	total: 20.1s	remaining: 14m 35s
# 785:	learn: 0.6607755	total: 20.1s	remaining: 14m 35s
# 786:	learn: 0.6607703	total: 20.1s	remaining: 14m 35s
# 787:	learn: 0.6607639	total: 20.2s	remaining: 14m 35s
# 788:	learn: 0.6607569	total: 20.2s	remaining: 14m 36s
# 789:	learn: 0.6607492	total: 20.2s	remaining: 14m 36s
# 790:	learn: 0.6607446	total: 20.3s	remaining: 14m 37s
# 791:	learn: 0.6607382	total: 20.3s	remaining: 14m 37s
# 792:	learn: 0.6607321	total: 20.3s	remaining: 14m 36s
# 793:	learn: 0.6607274	total: 20.4s	remaining: 14m 36s
# 794:	learn: 0.6607217	total: 20.4s	remaining: 14m 36s
# 795:	learn: 0.6607118	total: 20.4s	remaining: 14m 36s
# 796:	learn: 0.6607045	total: 20.4s	remaining: 14m 36s
# 797:	learn: 0.6606972	total: 20.5s	remaining: 14m 37s
# 798:	learn: 0.6606895	total: 20.5s	remaining: 14m 37s
# 799:	learn: 0.6606804	total: 20.5s	remaining: 14m 37s
# 800:	learn: 0.6606734	total: 20.5s	remaining: 14m 37s
# 801:	learn: 0.6606667	total: 20.6s	remaining: 14m 37s
# 802:	learn: 0.6606587	total: 20.6s	remaining: 14m 37s
# 803:	learn: 0.6606524	total: 20.6s	remaining: 14m 37s
# 804:	learn: 0.6606468	total: 20.7s	remaining: 14m 37s
# 805:	learn: 0.6606422	total: 20.7s	remaining: 14m 37s
# 806:	learn: 0.6606364	total: 20.7s	remaining: 14m 37s
# 807:	learn: 0.6606292	total: 20.7s	remaining: 14m 37s
# 808:	learn: 0.6606218	total: 20.8s	remaining: 14m 37s
# 809:	learn: 0.6606156	total: 20.8s	remaining: 14m 37s
# 810:	learn: 0.6606074	total: 20.8s	remaining: 14m 37s
# 811:	learn: 0.6606001	total: 20.9s	remaining: 14m 37s
# 812:	learn: 0.6605957	total: 20.9s	remaining: 14m 38s
# 813:	learn: 0.6605892	total: 20.9s	remaining: 14m 38s
# 814:	learn: 0.6605846	total: 20.9s	remaining: 14m 38s
# 815:	learn: 0.6605785	total: 21s	remaining: 14m 38s
# 816:	learn: 0.6605736	total: 21s	remaining: 14m 38s
# 817:	learn: 0.6605638	total: 21s	remaining: 14m 38s
# 818:	learn: 0.6605582	total: 21s	remaining: 14m 38s
# 819:	learn: 0.6605551	total: 21.1s	remaining: 14m 38s
# 820:	learn: 0.6605492	total: 21.1s	remaining: 14m 38s
# 821:	learn: 0.6605438	total: 21.1s	remaining: 14m 38s
# 822:	learn: 0.6605396	total: 21.1s	remaining: 14m 38s
# 823:	learn: 0.6605335	total: 21.2s	remaining: 14m 38s
# 824:	learn: 0.6605280	total: 21.2s	remaining: 14m 38s
# 825:	learn: 0.6605229	total: 21.2s	remaining: 14m 38s
# 826:	learn: 0.6605191	total: 21.3s	remaining: 14m 38s
# 827:	learn: 0.6605125	total: 21.3s	remaining: 14m 38s
# 828:	learn: 0.6605056	total: 21.3s	remaining: 14m 38s
# 829:	learn: 0.6605008	total: 21.4s	remaining: 14m 39s
# 830:	learn: 0.6604969	total: 21.4s	remaining: 14m 39s
# 831:	learn: 0.6604901	total: 21.4s	remaining: 14m 39s
# 832:	learn: 0.6604851	total: 21.4s	remaining: 14m 39s
# 833:	learn: 0.6604786	total: 21.5s	remaining: 14m 39s
# 834:	learn: 0.6604703	total: 21.5s	remaining: 14m 39s
# 835:	learn: 0.6604658	total: 21.5s	remaining: 14m 39s
# 836:	learn: 0.6604589	total: 21.6s	remaining: 14m 41s
# 837:	learn: 0.6604511	total: 21.6s	remaining: 14m 41s
# 838:	learn: 0.6604461	total: 21.7s	remaining: 14m 41s
# 839:	learn: 0.6604435	total: 21.7s	remaining: 14m 41s
# 840:	learn: 0.6604345	total: 21.7s	remaining: 14m 41s
# 841:	learn: 0.6604246	total: 21.7s	remaining: 14m 41s
# 842:	learn: 0.6604181	total: 21.8s	remaining: 14m 41s
# 843:	learn: 0.6604135	total: 21.8s	remaining: 14m 41s
# 844:	learn: 0.6604084	total: 21.8s	remaining: 14m 41s
# 845:	learn: 0.6604038	total: 21.8s	remaining: 14m 41s
# 846:	learn: 0.6603988	total: 21.9s	remaining: 14m 42s
# 847:	learn: 0.6603905	total: 21.9s	remaining: 14m 42s
# 848:	learn: 0.6603849	total: 21.9s	remaining: 14m 42s
# 849:	learn: 0.6603788	total: 22s	remaining: 14m 42s
# 850:	learn: 0.6603752	total: 22s	remaining: 14m 42s
# 851:	learn: 0.6603697	total: 22s	remaining: 14m 42s
# 852:	learn: 0.6603635	total: 22s	remaining: 14m 42s
# 853:	learn: 0.6603563	total: 22.1s	remaining: 14m 42s
# 854:	learn: 0.6603502	total: 22.1s	remaining: 14m 42s
# 855:	learn: 0.6603428	total: 22.1s	remaining: 14m 42s
# 856:	learn: 0.6603382	total: 22.1s	remaining: 14m 42s
# 857:	learn: 0.6603318	total: 22.2s	remaining: 14m 42s
# 858:	learn: 0.6603246	total: 22.2s	remaining: 14m 42s
# 859:	learn: 0.6603199	total: 22.2s	remaining: 14m 42s
# 860:	learn: 0.6603168	total: 22.3s	remaining: 14m 42s
# 861:	learn: 0.6603112	total: 22.3s	remaining: 14m 42s
# 862:	learn: 0.6603080	total: 22.3s	remaining: 14m 42s
# 863:	learn: 0.6603043	total: 22.3s	remaining: 14m 42s
# 864:	learn: 0.6602988	total: 22.4s	remaining: 14m 42s
# 865:	learn: 0.6602930	total: 22.4s	remaining: 14m 42s
# 866:	learn: 0.6602877	total: 22.4s	remaining: 14m 42s
# 867:	learn: 0.6602830	total: 22.5s	remaining: 14m 42s
# 868:	learn: 0.6602789	total: 22.5s	remaining: 14m 43s
# 869:	learn: 0.6602722	total: 22.5s	remaining: 14m 43s
# 870:	learn: 0.6602696	total: 22.5s	remaining: 14m 43s
# 871:	learn: 0.6602618	total: 22.6s	remaining: 14m 43s
# 872:	learn: 0.6602556	total: 22.6s	remaining: 14m 43s
# 873:	learn: 0.6602496	total: 22.6s	remaining: 14m 43s
# 874:	learn: 0.6602448	total: 22.6s	remaining: 14m 43s
# 875:	learn: 0.6602406	total: 22.7s	remaining: 14m 43s
# 876:	learn: 0.6602338	total: 22.7s	remaining: 14m 43s
# 877:	learn: 0.6602278	total: 22.7s	remaining: 14m 43s
# 878:	learn: 0.6602224	total: 22.8s	remaining: 14m 43s
# 879:	learn: 0.6602161	total: 22.8s	remaining: 14m 43s
# 880:	learn: 0.6602119	total: 22.8s	remaining: 14m 43s
# 881:	learn: 0.6602039	total: 22.8s	remaining: 14m 43s
# 882:	learn: 0.6601946	total: 22.9s	remaining: 14m 43s
# 883:	learn: 0.6601884	total: 22.9s	remaining: 14m 43s
# 884:	learn: 0.6601828	total: 22.9s	remaining: 14m 43s
# 885:	learn: 0.6601796	total: 22.9s	remaining: 14m 43s
# 886:	learn: 0.6601754	total: 23s	remaining: 14m 43s
# 887:	learn: 0.6601685	total: 23s	remaining: 14m 43s
# 888:	learn: 0.6601624	total: 23s	remaining: 14m 43s
# 889:	learn: 0.6601586	total: 23.1s	remaining: 14m 43s
# 890:	learn: 0.6601524	total: 23.1s	remaining: 14m 43s
# 891:	learn: 0.6601461	total: 23.1s	remaining: 14m 43s
# 892:	learn: 0.6601416	total: 23.1s	remaining: 14m 43s
# ...
# 34714:	learn: 0.5963417	total: 16m 45s	remaining: 8.26s
# 34715:	learn: 0.5963413	total: 16m 45s	remaining: 8.23s
# 34716:	learn: 0.5963396	total: 16m 45s	remaining: 8.2s
# 34717:	learn: 0.5963379	total: 16m 45s	remaining: 8.17s
# 34718:	learn: 0.5963366	total: 16m 46s	remaining: 8.14s
# 34719:	learn: 0.5963351	total: 16m 46s	remaining: 8.11s
# 34720:	learn: 0.5963332	total: 16m 46s	remaining: 8.08s
# 34721:	learn: 0.5963323	total: 16m 46s	remaining: 8.05s
# 34722:	learn: 0.5963294	total: 16m 46s	remaining: 8.03s
# 34723:	learn: 0.5963288	total: 16m 46s	remaining: 8s
# 34724:	learn: 0.5963269	total: 16m 46s	remaining: 7.97s
# 34725:	learn: 0.5963253	total: 16m 46s	remaining: 7.94s
# 34726:	learn: 0.5963235	total: 16m 46s	remaining: 7.91s
# 34727:	learn: 0.5963210	total: 16m 46s	remaining: 7.88s
# 34728:	learn: 0.5963196	total: 16m 46s	remaining: 7.85s
# 34729:	learn: 0.5963188	total: 16m 46s	remaining: 7.82s
# 34730:	learn: 0.5963171	total: 16m 46s	remaining: 7.79s
# 34731:	learn: 0.5963163	total: 16m 46s	remaining: 7.77s
# 34732:	learn: 0.5963146	total: 16m 46s	remaining: 7.74s
# 34733:	learn: 0.5963134	total: 16m 46s	remaining: 7.71s
# 34734:	learn: 0.5963115	total: 16m 46s	remaining: 7.68s
# 34735:	learn: 0.5963108	total: 16m 46s	remaining: 7.65s
# 34736:	learn: 0.5963102	total: 16m 46s	remaining: 7.62s
# 34737:	learn: 0.5963092	total: 16m 46s	remaining: 7.59s
# 34738:	learn: 0.5963083	total: 16m 46s	remaining: 7.56s
# 34739:	learn: 0.5963070	total: 16m 46s	remaining: 7.53s
# 34740:	learn: 0.5963059	total: 16m 46s	remaining: 7.5s
# 34741:	learn: 0.5963055	total: 16m 46s	remaining: 7.48s
# 34742:	learn: 0.5963050	total: 16m 46s	remaining: 7.45s
# 34743:	learn: 0.5963041	total: 16m 46s	remaining: 7.42s
# 34744:	learn: 0.5963031	total: 16m 46s	remaining: 7.39s
# 34745:	learn: 0.5963019	total: 16m 46s	remaining: 7.36s
# 34746:	learn: 0.5963001	total: 16m 46s	remaining: 7.33s
# 34747:	learn: 0.5962992	total: 16m 46s	remaining: 7.3s
# 34748:	learn: 0.5962986	total: 16m 46s	remaining: 7.27s
# 34749:	learn: 0.5962983	total: 16m 47s	remaining: 7.24s
# 34750:	learn: 0.5962956	total: 16m 47s	remaining: 7.21s
# 34751:	learn: 0.5962919	total: 16m 47s	remaining: 7.19s
# 34752:	learn: 0.5962909	total: 16m 47s	remaining: 7.16s
# 34753:	learn: 0.5962889	total: 16m 47s	remaining: 7.13s
# 34754:	learn: 0.5962883	total: 16m 47s	remaining: 7.1s
# 34755:	learn: 0.5962860	total: 16m 47s	remaining: 7.07s
# 34756:	learn: 0.5962850	total: 16m 47s	remaining: 7.04s
# 34757:	learn: 0.5962830	total: 16m 47s	remaining: 7.01s
# 34758:	learn: 0.5962816	total: 16m 47s	remaining: 6.98s
# 34759:	learn: 0.5962804	total: 16m 47s	remaining: 6.95s
# 34760:	learn: 0.5962786	total: 16m 47s	remaining: 6.93s
# 34761:	learn: 0.5962761	total: 16m 47s	remaining: 6.9s
# 34762:	learn: 0.5962727	total: 16m 47s	remaining: 6.87s
# 34763:	learn: 0.5962714	total: 16m 47s	remaining: 6.84s
# 34764:	learn: 0.5962701	total: 16m 47s	remaining: 6.81s
# 34765:	learn: 0.5962666	total: 16m 47s	remaining: 6.78s
# 34766:	learn: 0.5962659	total: 16m 47s	remaining: 6.75s
# 34767:	learn: 0.5962629	total: 16m 47s	remaining: 6.72s
# 34768:	learn: 0.5962617	total: 16m 47s	remaining: 6.69s
# 34769:	learn: 0.5962605	total: 16m 47s	remaining: 6.67s
# 34770:	learn: 0.5962591	total: 16m 47s	remaining: 6.64s
# 34771:	learn: 0.5962570	total: 16m 47s	remaining: 6.61s
# 34772:	learn: 0.5962560	total: 16m 47s	remaining: 6.58s
# 34773:	learn: 0.5962554	total: 16m 47s	remaining: 6.55s
# 34774:	learn: 0.5962536	total: 16m 47s	remaining: 6.52s
# 34775:	learn: 0.5962502	total: 16m 47s	remaining: 6.49s
# 34776:	learn: 0.5962487	total: 16m 47s	remaining: 6.46s
# 34777:	learn: 0.5962478	total: 16m 47s	remaining: 6.43s
# 34778:	learn: 0.5962472	total: 16m 47s	remaining: 6.4s
# 34779:	learn: 0.5962445	total: 16m 47s	remaining: 6.38s
# 34780:	learn: 0.5962420	total: 16m 47s	remaining: 6.35s
# 34781:	learn: 0.5962392	total: 16m 48s	remaining: 6.32s
# 34782:	learn: 0.5962389	total: 16m 48s	remaining: 6.29s
# 34783:	learn: 0.5962361	total: 16m 48s	remaining: 6.26s
# 34784:	learn: 0.5962354	total: 16m 48s	remaining: 6.23s
# 34785:	learn: 0.5962341	total: 16m 48s	remaining: 6.2s
# 34786:	learn: 0.5962321	total: 16m 48s	remaining: 6.17s
# 34787:	learn: 0.5962307	total: 16m 48s	remaining: 6.14s
# 34788:	learn: 0.5962299	total: 16m 48s	remaining: 6.12s
# 34789:	learn: 0.5962286	total: 16m 48s	remaining: 6.09s
# 34790:	learn: 0.5962274	total: 16m 48s	remaining: 6.06s
# 34791:	learn: 0.5962263	total: 16m 48s	remaining: 6.03s
# 34792:	learn: 0.5962246	total: 16m 48s	remaining: 6s
# 34793:	learn: 0.5962222	total: 16m 48s	remaining: 5.97s
# 34794:	learn: 0.5962208	total: 16m 48s	remaining: 5.94s
# 34795:	learn: 0.5962201	total: 16m 48s	remaining: 5.91s
# 34796:	learn: 0.5962182	total: 16m 48s	remaining: 5.88s
# 34797:	learn: 0.5962173	total: 16m 48s	remaining: 5.85s
# 34798:	learn: 0.5962163	total: 16m 48s	remaining: 5.83s
# 34799:	learn: 0.5962150	total: 16m 48s	remaining: 5.8s
# 34800:	learn: 0.5962130	total: 16m 48s	remaining: 5.77s
# 34801:	learn: 0.5962123	total: 16m 48s	remaining: 5.74s
# 34802:	learn: 0.5962117	total: 16m 48s	remaining: 5.71s
# 34803:	learn: 0.5962103	total: 16m 48s	remaining: 5.68s
# 34804:	learn: 0.5962078	total: 16m 48s	remaining: 5.65s
# 34805:	learn: 0.5962062	total: 16m 48s	remaining: 5.62s
# 34806:	learn: 0.5962043	total: 16m 48s	remaining: 5.59s
# 34807:	learn: 0.5962015	total: 16m 48s	remaining: 5.56s
# 34808:	learn: 0.5962000	total: 16m 48s	remaining: 5.54s
# 34809:	learn: 0.5961982	total: 16m 48s	remaining: 5.51s
# 34810:	learn: 0.5961959	total: 16m 48s	remaining: 5.48s
# 34811:	learn: 0.5961938	total: 16m 48s	remaining: 5.45s
# 34812:	learn: 0.5961927	total: 16m 48s	remaining: 5.42s
# 34813:	learn: 0.5961913	total: 16m 49s	remaining: 5.39s
# 34814:	learn: 0.5961869	total: 16m 49s	remaining: 5.36s
# 34815:	learn: 0.5961860	total: 16m 49s	remaining: 5.33s
# 34816:	learn: 0.5961846	total: 16m 49s	remaining: 5.3s
# 34817:	learn: 0.5961840	total: 16m 49s	remaining: 5.28s
# 34818:	learn: 0.5961838	total: 16m 49s	remaining: 5.25s
# 34819:	learn: 0.5961831	total: 16m 49s	remaining: 5.22s
# 34820:	learn: 0.5961820	total: 16m 49s	remaining: 5.19s
# 34821:	learn: 0.5961803	total: 16m 49s	remaining: 5.16s
# 34822:	learn: 0.5961784	total: 16m 49s	remaining: 5.13s
# 34823:	learn: 0.5961759	total: 16m 49s	remaining: 5.1s
# 34824:	learn: 0.5961744	total: 16m 49s	remaining: 5.07s
# 34825:	learn: 0.5961731	total: 16m 49s	remaining: 5.04s
# 34826:	learn: 0.5961716	total: 16m 49s	remaining: 5.01s
# 34827:	learn: 0.5961694	total: 16m 49s	remaining: 4.99s
# 34828:	learn: 0.5961686	total: 16m 49s	remaining: 4.96s
# 34829:	learn: 0.5961673	total: 16m 49s	remaining: 4.93s
# 34830:	learn: 0.5961667	total: 16m 49s	remaining: 4.9s
# 34831:	learn: 0.5961649	total: 16m 49s	remaining: 4.87s
# 34832:	learn: 0.5961639	total: 16m 49s	remaining: 4.84s
# 34833:	learn: 0.5961624	total: 16m 49s	remaining: 4.81s
# 34834:	learn: 0.5961619	total: 16m 49s	remaining: 4.78s
# 34835:	learn: 0.5961602	total: 16m 49s	remaining: 4.75s
# 34836:	learn: 0.5961597	total: 16m 49s	remaining: 4.72s
# 34837:	learn: 0.5961575	total: 16m 49s	remaining: 4.7s
# 34838:	learn: 0.5961562	total: 16m 49s	remaining: 4.67s
# 34839:	learn: 0.5961548	total: 16m 49s	remaining: 4.64s
# 34840:	learn: 0.5961523	total: 16m 49s	remaining: 4.61s
# 34841:	learn: 0.5961509	total: 16m 49s	remaining: 4.58s
# 34842:	learn: 0.5961494	total: 16m 49s	remaining: 4.55s
# 34843:	learn: 0.5961485	total: 16m 49s	remaining: 4.52s
# 34844:	learn: 0.5961482	total: 16m 49s	remaining: 4.49s
# 34845:	learn: 0.5961467	total: 16m 50s	remaining: 4.46s
# 34846:	learn: 0.5961451	total: 16m 50s	remaining: 4.43s
# 34847:	learn: 0.5961438	total: 16m 50s	remaining: 4.41s
# 34848:	learn: 0.5961436	total: 16m 50s	remaining: 4.38s
# 34849:	learn: 0.5961422	total: 16m 50s	remaining: 4.35s
# 34850:	learn: 0.5961410	total: 16m 50s	remaining: 4.32s
# 34851:	learn: 0.5961401	total: 16m 50s	remaining: 4.29s
# 34852:	learn: 0.5961385	total: 16m 50s	remaining: 4.26s
# 34853:	learn: 0.5961362	total: 16m 50s	remaining: 4.23s
# 34854:	learn: 0.5961360	total: 16m 50s	remaining: 4.2s
# 34855:	learn: 0.5961344	total: 16m 50s	remaining: 4.17s
# 34856:	learn: 0.5961327	total: 16m 50s	remaining: 4.14s
# 34857:	learn: 0.5961303	total: 16m 50s	remaining: 4.12s
# 34858:	learn: 0.5961287	total: 16m 50s	remaining: 4.09s
# 34859:	learn: 0.5961280	total: 16m 50s	remaining: 4.06s
# 34860:	learn: 0.5961268	total: 16m 50s	remaining: 4.03s
# 34861:	learn: 0.5961262	total: 16m 50s	remaining: 4s
# 34862:	learn: 0.5961248	total: 16m 50s	remaining: 3.97s
# 34863:	learn: 0.5961230	total: 16m 50s	remaining: 3.94s
# 34864:	learn: 0.5961215	total: 16m 50s	remaining: 3.91s
# 34865:	learn: 0.5961203	total: 16m 50s	remaining: 3.88s
# 34866:	learn: 0.5961192	total: 16m 50s	remaining: 3.85s
# 34867:	learn: 0.5961180	total: 16m 50s	remaining: 3.83s
# 34868:	learn: 0.5961162	total: 16m 50s	remaining: 3.8s
# 34869:	learn: 0.5961154	total: 16m 50s	remaining: 3.77s
# 34870:	learn: 0.5961138	total: 16m 50s	remaining: 3.74s
# 34871:	learn: 0.5961122	total: 16m 50s	remaining: 3.71s
# 34872:	learn: 0.5961099	total: 16m 50s	remaining: 3.68s
# 34873:	learn: 0.5961061	total: 16m 50s	remaining: 3.65s
# 34874:	learn: 0.5961042	total: 16m 50s	remaining: 3.62s
# 34875:	learn: 0.5961033	total: 16m 50s	remaining: 3.59s
# 34876:	learn: 0.5961018	total: 16m 50s	remaining: 3.56s
# 34877:	learn: 0.5961002	total: 16m 51s	remaining: 3.54s
# 34878:	learn: 0.5960994	total: 16m 51s	remaining: 3.51s
# 34879:	learn: 0.5960981	total: 16m 51s	remaining: 3.48s
# 34880:	learn: 0.5960978	total: 16m 51s	remaining: 3.45s
# 34881:	learn: 0.5960965	total: 16m 51s	remaining: 3.42s
# 34882:	learn: 0.5960953	total: 16m 51s	remaining: 3.39s
# 34883:	learn: 0.5960945	total: 16m 51s	remaining: 3.36s
# 34884:	learn: 0.5960938	total: 16m 51s	remaining: 3.33s
# 34885:	learn: 0.5960933	total: 16m 51s	remaining: 3.3s
# 34886:	learn: 0.5960928	total: 16m 51s	remaining: 3.27s
# 34887:	learn: 0.5960920	total: 16m 51s	remaining: 3.25s
# 34888:	learn: 0.5960914	total: 16m 51s	remaining: 3.22s
# 34889:	learn: 0.5960895	total: 16m 51s	remaining: 3.19s
# 34890:	learn: 0.5960885	total: 16m 51s	remaining: 3.16s
# 34891:	learn: 0.5960869	total: 16m 51s	remaining: 3.13s
# 34892:	learn: 0.5960864	total: 16m 51s	remaining: 3.1s
# 34893:	learn: 0.5960857	total: 16m 51s	remaining: 3.07s
# 34894:	learn: 0.5960838	total: 16m 51s	remaining: 3.04s
# 34895:	learn: 0.5960823	total: 16m 51s	remaining: 3.02s
# 34896:	learn: 0.5960812	total: 16m 51s	remaining: 2.99s
# 34897:	learn: 0.5960796	total: 16m 51s	remaining: 2.96s
# 34898:	learn: 0.5960779	total: 16m 51s	remaining: 2.93s
# 34899:	learn: 0.5960755	total: 16m 51s	remaining: 2.9s
# 34900:	learn: 0.5960732	total: 16m 51s	remaining: 2.87s
# 34901:	learn: 0.5960711	total: 16m 51s	remaining: 2.84s
# 34902:	learn: 0.5960703	total: 16m 51s	remaining: 2.81s
# 34903:	learn: 0.5960687	total: 16m 51s	remaining: 2.78s
# 34904:	learn: 0.5960681	total: 16m 51s	remaining: 2.75s
# 34905:	learn: 0.5960674	total: 16m 51s	remaining: 2.73s
# 34906:	learn: 0.5960659	total: 16m 51s	remaining: 2.7s
# 34907:	learn: 0.5960640	total: 16m 52s	remaining: 2.67s
# 34908:	learn: 0.5960628	total: 16m 52s	remaining: 2.64s
# 34909:	learn: 0.5960619	total: 16m 52s	remaining: 2.61s
# 34910:	learn: 0.5960610	total: 16m 52s	remaining: 2.58s
# 34911:	learn: 0.5960606	total: 16m 52s	remaining: 2.55s
# 34912:	learn: 0.5960589	total: 16m 52s	remaining: 2.52s
# 34913:	learn: 0.5960571	total: 16m 52s	remaining: 2.49s
# 34914:	learn: 0.5960568	total: 16m 52s	remaining: 2.46s
# 34915:	learn: 0.5960564	total: 16m 52s	remaining: 2.44s
# 34916:	learn: 0.5960555	total: 16m 52s	remaining: 2.41s
# 34917:	learn: 0.5960549	total: 16m 52s	remaining: 2.38s
# 34918:	learn: 0.5960540	total: 16m 52s	remaining: 2.35s
# 34919:	learn: 0.5960497	total: 16m 52s	remaining: 2.32s
# 34920:	learn: 0.5960472	total: 16m 52s	remaining: 2.29s
# 34921:	learn: 0.5960466	total: 16m 52s	remaining: 2.26s
# 34922:	learn: 0.5960439	total: 16m 52s	remaining: 2.23s
# 34923:	learn: 0.5960414	total: 16m 52s	remaining: 2.2s
# 34924:	learn: 0.5960412	total: 16m 52s	remaining: 2.17s
# 34925:	learn: 0.5960400	total: 16m 52s	remaining: 2.15s
# 34926:	learn: 0.5960397	total: 16m 52s	remaining: 2.12s
# 34927:	learn: 0.5960384	total: 16m 52s	remaining: 2.09s
# 34928:	learn: 0.5960358	total: 16m 52s	remaining: 2.06s
# 34929:	learn: 0.5960333	total: 16m 52s	remaining: 2.03s
# 34930:	learn: 0.5960324	total: 16m 52s	remaining: 2s
# 34931:	learn: 0.5960304	total: 16m 52s	remaining: 1.97s
# 34932:	learn: 0.5960294	total: 16m 52s	remaining: 1.94s
# 34933:	learn: 0.5960287	total: 16m 52s	remaining: 1.91s
# 34934:	learn: 0.5960266	total: 16m 52s	remaining: 1.88s
# 34935:	learn: 0.5960256	total: 16m 52s	remaining: 1.85s
# 34936:	learn: 0.5960241	total: 16m 52s	remaining: 1.83s
# 34937:	learn: 0.5960230	total: 16m 52s	remaining: 1.8s
# 34938:	learn: 0.5960224	total: 16m 52s	remaining: 1.77s
# 34939:	learn: 0.5960215	total: 16m 53s	remaining: 1.74s
# 34940:	learn: 0.5960209	total: 16m 53s	remaining: 1.71s
# 34941:	learn: 0.5960191	total: 16m 53s	remaining: 1.68s
# 34942:	learn: 0.5960172	total: 16m 53s	remaining: 1.65s
# 34943:	learn: 0.5960167	total: 16m 53s	remaining: 1.62s
# 34944:	learn: 0.5960159	total: 16m 53s	remaining: 1.59s
# 34945:	learn: 0.5960139	total: 16m 53s	remaining: 1.56s
# 34946:	learn: 0.5960128	total: 16m 53s	remaining: 1.54s
# 34947:	learn: 0.5960107	total: 16m 53s	remaining: 1.51s
# 34948:	learn: 0.5960088	total: 16m 53s	remaining: 1.48s
# 34949:	learn: 0.5960074	total: 16m 53s	remaining: 1.45s
# 34950:	learn: 0.5960060	total: 16m 53s	remaining: 1.42s
# 34951:	learn: 0.5960050	total: 16m 53s	remaining: 1.39s
# 34952:	learn: 0.5960042	total: 16m 53s	remaining: 1.36s
# 34953:	learn: 0.5960029	total: 16m 53s	remaining: 1.33s
# 34954:	learn: 0.5960015	total: 16m 53s	remaining: 1.3s
# 34955:	learn: 0.5960006	total: 16m 53s	remaining: 1.27s
# 34956:	learn: 0.5959994	total: 16m 53s	remaining: 1.25s
# 34957:	learn: 0.5959981	total: 16m 53s	remaining: 1.22s
# 34958:	learn: 0.5959969	total: 16m 53s	remaining: 1.19s
# 34959:	learn: 0.5959960	total: 16m 53s	remaining: 1.16s
# 34960:	learn: 0.5959955	total: 16m 53s	remaining: 1.13s
# 34961:	learn: 0.5959947	total: 16m 53s	remaining: 1.1s
# 34962:	learn: 0.5959938	total: 16m 53s	remaining: 1.07s
# 34963:	learn: 0.5959915	total: 16m 53s	remaining: 1.04s
# 34964:	learn: 0.5959906	total: 16m 53s	remaining: 1.01s
# 34965:	learn: 0.5959883	total: 16m 53s	remaining: 986ms
# 34966:	learn: 0.5959871	total: 16m 53s	remaining: 957ms
# 34967:	learn: 0.5959857	total: 16m 53s	remaining: 928ms
# 34968:	learn: 0.5959847	total: 16m 53s	remaining: 899ms
# 34969:	learn: 0.5959830	total: 16m 54s	remaining: 870ms
# 34970:	learn: 0.5959819	total: 16m 54s	remaining: 841ms
# 34971:	learn: 0.5959814	total: 16m 54s	remaining: 812ms
# 34972:	learn: 0.5959797	total: 16m 54s	remaining: 783ms
# 34973:	learn: 0.5959789	total: 16m 54s	remaining: 754ms
# 34974:	learn: 0.5959773	total: 16m 54s	remaining: 725ms
# 34975:	learn: 0.5959755	total: 16m 54s	remaining: 696ms
# 34976:	learn: 0.5959746	total: 16m 54s	remaining: 667ms
# 34977:	learn: 0.5959731	total: 16m 54s	remaining: 638ms
# 34978:	learn: 0.5959707	total: 16m 54s	remaining: 609ms
# 34979:	learn: 0.5959695	total: 16m 54s	remaining: 580ms
# 34980:	learn: 0.5959685	total: 16m 54s	remaining: 551ms
# 34981:	learn: 0.5959672	total: 16m 54s	remaining: 522ms
# 34982:	learn: 0.5959664	total: 16m 54s	remaining: 493ms
# 34983:	learn: 0.5959648	total: 16m 54s	remaining: 464ms
# 34984:	learn: 0.5959623	total: 16m 54s	remaining: 435ms
# 34985:	learn: 0.5959620	total: 16m 54s	remaining: 406ms
# 34986:	learn: 0.5959611	total: 16m 54s	remaining: 377ms
# 34987:	learn: 0.5959582	total: 16m 54s	remaining: 348ms
# 34988:	learn: 0.5959572	total: 16m 54s	remaining: 319ms
# 34989:	learn: 0.5959561	total: 16m 54s	remaining: 290ms
# 34990:	learn: 0.5959550	total: 16m 54s	remaining: 261ms
# 34991:	learn: 0.5959541	total: 16m 54s	remaining: 232ms
# 34992:	learn: 0.5959522	total: 16m 54s	remaining: 203ms
# 34993:	learn: 0.5959518	total: 16m 54s	remaining: 174ms
# 34994:	learn: 0.5959509	total: 16m 54s	remaining: 145ms
# 34995:	learn: 0.5959502	total: 16m 54s	remaining: 116ms
# 34996:	learn: 0.5959478	total: 16m 54s	remaining: 87ms
# 34997:	learn: 0.5959454	total: 16m 54s	remaining: 58ms
# 34998:	learn: 0.5959448	total: 16m 54s	remaining: 29ms
# 34999:	learn: 0.5959440	total: 16m 55s	remaining: 0us

# %%
xgb_regressor.fit(X_scaled, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
lgbm_regressor.fit(X_scaled, y)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017746 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2350
# [LightGBM] [Info] Number of data points in the train set: 312278, number of used features: 83
# [LightGBM] [Info] Start training from score 0.189211
# LGBMRegressor()

# %%
# cb_y_pred = cb_regressor.predict(X_test)
# xgb_y_pred = xgb_regressor.predict(X_test)
# lgbm_y_pred = lgbm_regressor.predict(X_test)

# ensemble_y_pred = (
#     (0.6 * cb_y_pred) +
#     (0.4 * xgb_y_pred)
#     # (0.2 * lgbm_y_pred) 
# )
# print('RMSE:', np.sqrt(mean_squared_error(y_test, ensemble_y_pred)))

# %%
submission = pd.read_csv("../../datasets/sample_submission.csv")

cat_y_pred = cb_regressor.predict(test_scaled)
xgb_y_pred = xgb_regressor.predict(test_scaled)
lgbm_y_pred = lgbm_regressor.predict(test_scaled)

ensembled_y_pred = (
   ( 0.6 * cat_y_pred ) +
   ( 0.1 * xgb_y_pred ) +
   ( 0.3 * lgbm_y_pred ) 
)

submission['rain_1h'] = ensembled_y_pred
submission['rain_1h'] = submission['rain_1h'].apply(lambda x: 0. if x < 0 else x)
submission.to_csv('../predictions/submission5_rang.csv', index=False)
